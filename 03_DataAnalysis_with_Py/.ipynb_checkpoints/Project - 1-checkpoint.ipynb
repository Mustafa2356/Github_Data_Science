# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Examining the dataset
# **INSTRUCTIONS**
#
# *   Import pandas using the alias ``pd``.
# *   Read the file police.csv into a DataFrame named ``ri``
# *   Examine the first 5 rows of the ``DataFrame`` (known as the ``"head"``).
# *   Count the number of missing values in each column: Use ``.isnull()`` to check which ``DataFrame`` elements are missing, and then take the ``.sum()`` to count the number of ``True`` values in each column.

# %%
pwd
# Out:
# 'C:\\Users\\Mustafa\\Desktop\\MyWorkSpace\\Github_Data_Science\\03_DataAnalysis_with_Py'

# %%
# ri = pd.read_csv("police.csv", delimiter = ";")
ri = pd.read_csv("police.csv", sep = ",")
# Out:
# C:\Users\Mustafa\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (8,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
ri.head(5)
# Out:
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# 2          NaN                    NaN                 0           NaN  ...
# 3          NaN                    NaN               500             M  ...
# 4          NaN                    NaN               500             M  ...
#
#    search_conducted  search_type_raw search_type contraband_found  \
# 0             False              NaN         NaN            False
# 1             False              NaN         NaN            False
# 2             False              NaN         NaN            False
# 3             False              NaN         NaN            False
# 4             False              NaN         NaN            False
#
#   stop_outcome is_arrested stop_duration out_of_state drugs_related_stop  \
# 0     Citation       False      0-15 Min        False              False
# 1     Citation       False     16-30 Min        False              False
# 2          NaN         NaN           NaN          NaN              False
# 3     Citation       False      0-15 Min        False              False
# 4     Citation       False      0-15 Min        False              False
#
#    district
# 0   Zone K1
# 1   Zone X4
# 2   Zone X1
# 3   Zone X4
# 4   Zone X4
#
# [5 rows x 26 columns]

# %%
ri.shape
# Out:
# (509681, 26)

# %%
ri=ri.iloc[1:50000] # iloc indexlerle calisir ilk 50 binlik satirla calisiyoruz.

# %%
len(ri.head())
# Out:
# 5

# %%
ri.isnull().sum() # ri ‘deki eksik değerlerin sayısını öğrenelim ve azalan şekilde sıralayalım.
# Out:
# id                           0
# state                        0
# stop_date                    0
# stop_time                    0
# location_raw                 0
# county_name              49999
# county_fips              49999
# fine_grained_location    49999
# police_department            0
# driver_gender             1990
# driver_age_raw            1971
# driver_age                2208
# driver_race_raw           1988
# driver_race               1988
# violation_raw             1988
# violation                 1988
# search_conducted             0
# search_type_raw          47987
# search_type              47987
# contraband_found             0
# stop_outcome              1988
# is_arrested               1988
# stop_duration             1988
# out_of_state              2203
# drugs_related_stop           0
# district                     0
# dtype: int64

# %%
ri.isnull().sum().sort_values(ascending=False) # df ‘deki eksik değerlerin sayısını öğrenelim ve azalan şekilde sıralayalım.
# Out:
# county_fips              49999
# county_name              49999
# fine_grained_location    49999
# search_type              47987
# search_type_raw          47987
# driver_age                2208
# out_of_state              2203
# driver_gender             1990
# driver_race               1988
# violation_raw             1988
# driver_race_raw           1988
# stop_outcome              1988
# is_arrested               1988
# stop_duration             1988
# violation                 1988
# driver_age_raw            1971
# stop_date                    0
# state                        0
# stop_time                    0
# location_raw                 0
# district                     0
# police_department            0
# drugs_related_stop           0
# search_conducted             0
# contraband_found             0
# id                           0
# dtype: int64

# %%
ri.shape
# Out:
# (49999, 26)

# %% [markdown]
# ## Dropping columns
# Often, a DataFrame will contain columns that are not useful to your analysis. Such columns should be dropped from the ``DataFrame``, to make it easier for you to focus on the remaining columns.
#
# You'll drop the ``county_name`` column because it only contains missing values, and you'll drop the ``state`` column because all of the traffic stops took place in one state (Rhode Island). Thus, these columns can be dropped because they contain no useful information.
#
# **INSTRUCTIONS**
#
# *   Examine the ``DataFrame``'s shape to find out the number of rows and columns.
#
# *   Drop the columns that almost consist of missing values.
#
# *   Examine the ``.shape`` again to verify that there are now two fewer columns.

# %%
# ri.drop(["state", "county_name"], axis = 1)
ri.drop(["state", "county_name"], axis = 1, inplace = True) # I droped this two colomns (degikleri kayd edecek sekilde sildik)
ri
# Out:
#                   id   stop_date stop_time location_raw  county_fips  \
# 1      RI-2005-00002  2005-01-02     20:30      Zone X4          NaN
# 2      RI-2005-00003  2005-01-04     11:30      Zone X1          NaN
# 3      RI-2005-00004  2005-01-04     12:55      Zone X4          NaN
# 4      RI-2005-00005  2005-01-06     01:30      Zone X4          NaN
# 5      RI-2005-00006  2005-01-12     08:05      Zone X1          NaN
# ...              ...         ...       ...          ...          ...
# 49995  RI-2006-35917  2006-08-08     22:45      Zone K3          NaN
# 49996  RI-2006-35918  2006-08-08     22:45      Zone K3          NaN
# 49997  RI-2006-35919  2006-08-08     22:53      Zone X4          NaN
# 49998  RI-2006-35920  2006-08-08     23:00      Zone K1          NaN
# 49999  RI-2006-35921  2006-08-08     23:00      Zone K3          NaN
#
#        fine_grained_location police_department driver_gender  driver_age_raw  \
# 1                        NaN               500             M          1987.0
# 2                        NaN                 0           NaN             NaN
# 3                        NaN               500             M          1986.0
# 4                        NaN               500             M          1978.0
# 5                        NaN                 0             M          1973.0
# ...                      ...               ...           ...             ...
# 49995                    NaN               300             M          1973.0
# 49996                    NaN               300             F          1971.0
# 49997                    NaN               500             M          1952.0
# 49998                    NaN               600             F          1982.0
# 49999                    NaN               300             M          1965.0
#
#        driver_age  ... search_conducted search_type_raw search_type  \
# 1            18.0  ...            False             NaN         NaN
# 2             NaN  ...            False             NaN         NaN
# 3            19.0  ...            False             NaN         NaN
# 4            27.0  ...            False             NaN         NaN
# 5            32.0  ...            False             NaN         NaN
# ...           ...  ...              ...             ...         ...
# 49995        33.0  ...            False             NaN         NaN
# 49996        35.0  ...            False             NaN         NaN
# 49997        54.0  ...            False             NaN         NaN
# 49998        24.0  ...            False             NaN         NaN
# 49999        41.0  ...            False             NaN         NaN
#
#       contraband_found stop_outcome is_arrested stop_duration  out_of_state  \
# 1                False     Citation       False     16-30 Min         False
# 2                False          NaN         NaN           NaN           NaN
# 3                False     Citation       False      0-15 Min         False
# 4                False     Citation       False      0-15 Min         False
# 5                False     Citation       False       30+ Min          True
# ...                ...          ...         ...           ...           ...
# 49995            False     Citation       False      0-15 Min         False
# 49996            False     Citation       False      0-15 Min          True
# 49997            False     Citation       False     16-30 Min          True
# 49998            False     Citation       False      0-15 Min         False
# 49999            False     Citation       False     16-30 Min         False
#
#       drugs_related_stop district
# 1                  False  Zone X4
# 2                  False  Zone X1
# 3                  False  Zone X4
# 4                  False  Zone X4
# 5                  False  Zone X1
# ...                  ...      ...
# 49995              False  Zone K3
# 49996              False  Zone K3
# 49997              False  Zone X4
# 49998              False  Zone K1
# 49999              False  Zone K3
#
# [49999 rows x 24 columns]

# %%
ri.shape # iki kolon kalici sekilde silindi
# Out:
# (49999, 24)

# %%
ri.drop(["county_fips", "fine_grained_location"], axis = 1, inplace = True) # bu kolonlarda tum veri eksik oldugundan siliyorum

# %%
ri.shape
# Out:
# (49999, 22)

# %% [markdown]
# ## Dropping rows
# When you know that a specific column will be critical to your analysis, and only a small fraction of rows are missing a value in that column, it often makes sense to remove those rows from the dataset.
#
# During this course, the ``driver_gender`` column will be critical to many of your analyses. Because only a small fraction of rows are missing ``driver_gender``, we'll drop those rows from the dataset.
#
# **INSTRUCTIONS**
#
# *   Count the number of missing values in each column.
#
# *   Drop all rows that are missing ``driver_gender`` by passing the column name to the subset parameter of ``.dropna()``.
# *   Count the number of missing values in each column again, to verify that none of the remaining rows are missing ``driver_gender``.
# *   Examine the ``DataFrame``'s ``.shape`` to see how many rows and columns remain.

# %%
print(ri.isnull().sum().sort_values(ascending=False))
# Out:
# search_type_raw       47987
# search_type           47987
# driver_age             2208
# out_of_state           2203
# driver_gender          1990
# stop_outcome           1988
# is_arrested            1988
# violation              1988
# driver_race            1988
# driver_race_raw        1988
# stop_duration          1988
# violation_raw          1988
# driver_age_raw         1971
# stop_date                 0
# police_department         0
# stop_time                 0
# location_raw              0
# district                  0
# drugs_related_stop        0
# search_conducted          0
# contraband_found          0
# id                        0
# dtype: int64

# %%
# ri.dropna() # her hangi bir index te satirda herhangi bir kolan altinda 
# bir tane bile NaN var ise o satiri dusuruyor, #bu direkt NaN bulunan İndex'i düşürür

# %%
ri.dropna(subset=['driver_gender'], inplace=True) # Sıra sayımız 50 binden 48 bine düştü
                                                # Our number of rows decreased from 50 thousand to 48 thousand
                                                # 'driver_gender' kolonu altinda NaN olan satirlari sildi
                                                # 'driver_gender' kolonu alti tamamen dolu verilerden olusuyor
ri
# ri.dropna(subset=['driver_gender'])
# Out:
#                   id   stop_date stop_time location_raw police_department  \
# 1      RI-2005-00002  2005-01-02     20:30      Zone X4               500
# 3      RI-2005-00004  2005-01-04     12:55      Zone X4               500
# 4      RI-2005-00005  2005-01-06     01:30      Zone X4               500
# 5      RI-2005-00006  2005-01-12     08:05      Zone X1                 0
# 6      RI-2005-00007  2005-01-18     08:15      Zone K3               300
# ...              ...         ...       ...          ...               ...
# 49995  RI-2006-35917  2006-08-08     22:45      Zone K3               300
# 49996  RI-2006-35918  2006-08-08     22:45      Zone K3               300
# 49997  RI-2006-35919  2006-08-08     22:53      Zone X4               500
# 49998  RI-2006-35920  2006-08-08     23:00      Zone K1               600
# 49999  RI-2006-35921  2006-08-08     23:00      Zone K3               300
#
#       driver_gender  driver_age_raw  driver_age driver_race_raw driver_race  \
# 1                 M          1987.0        18.0               W       White
# 3                 M          1986.0        19.0               W       White
# 4                 M          1978.0        27.0               B       Black
# 5                 M          1973.0        32.0               B       Black
# 6                 M          1965.0        40.0               W       White
# ...             ...             ...         ...             ...         ...
# 49995             M          1973.0        33.0               B       Black
# 49996             F          1971.0        35.0               B       Black
# 49997             M          1952.0        54.0               W       White
# 49998             F          1982.0        24.0               W       White
# 49999             M          1965.0        41.0               W       White
#
#        ... search_conducted search_type_raw search_type contraband_found  \
# 1      ...            False             NaN         NaN            False
# 3      ...            False             NaN         NaN            False
# 4      ...            False             NaN         NaN            False
# 5      ...            False             NaN         NaN            False
# 6      ...            False             NaN         NaN            False
# ...    ...              ...             ...         ...              ...
# 49995  ...            False             NaN         NaN            False
# 49996  ...            False             NaN         NaN            False
# 49997  ...            False             NaN         NaN            False
# 49998  ...            False             NaN         NaN            False
# 49999  ...            False             NaN         NaN            False
#
#       stop_outcome  is_arrested stop_duration out_of_state drugs_related_stop  \
# 1         Citation        False     16-30 Min        False              False
# 3         Citation        False      0-15 Min        False              False
# 4         Citation        False      0-15 Min        False              False
# 5         Citation        False       30+ Min         True              False
# 6         Citation        False      0-15 Min         True              False
# ...            ...          ...           ...          ...                ...
# 49995     Citation        False      0-15 Min        False              False
# 49996     Citation        False      0-15 Min         True              False
# 49997     Citation        False     16-30 Min         True              False
# 49998     Citation        False      0-15 Min        False              False
# 49999     Citation        False     16-30 Min        False              False
#
#       district
# 1      Zone X4
# 3      Zone X4
# 4      Zone X4
# 5      Zone X1
# 6      Zone K3
# ...        ...
# 49995  Zone K3
# 49996  Zone K3
# 49997  Zone X4
# 49998  Zone K1
# 49999  Zone K3
#
# [48009 rows x 22 columns]

# %%
ri.shape
# Out:
# (48009, 22)

# %%
ri["driver_gender"].value_counts() # Her bir değerin sütunda bulunma sayısına bakalım.
                                # Let's look at the number of times each value is in the column.
# Out:
# M    34700
# F    13309
# Name: driver_gender, dtype: int64

# %% [markdown]
# ## Fixing a data type
# We know that the ``is_arrested`` column currently has the ``object`` data type. In this exercise, we'll change the data type to ``bool``, which is the most suitable type for a column containing ``True`` and ``False`` values.
#
# Fixing the data type will enable us to use mathematical operations on the ``is_arrested`` column that would not be possible otherwise.
#
# **INSTRUCTIONS**
#
# *   Examine the head of the ``is_arrested`` column to verify that it contains ``True`` and ``False`` values.
# *   Check the current data type of ``is_arrested``.
# *   Use the ``.astype()`` method to convert ``is_arrested`` to a ``bool`` column.
# *   Check the new data type of ``is_arrested``, to confirm that it is now a ``bool`` column.

# %%
ri.is_arrested.head()
# Out:
# 1    False
# 3    False
# 4    False
# 5    False
# 6    False
# Name: is_arrested, dtype: object

# %%
print(ri.is_arrested.dtype)
# Out:
# object

# %%
ri['is_arrested'] = ri.is_arrested.astype(bool)

# %%
print(ri.is_arrested.dtype)
# Out:
# bool

# %%
ri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48009 entries, 1 to 49999
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  48009 non-null  object
#  1   stop_date           48009 non-null  object
#  2   stop_time           48009 non-null  object
#  3   location_raw        48009 non-null  object
#  4   police_department   48009 non-null  object
#  5   driver_gender       48009 non-null  object
#  6   driver_age_raw      48009 non-null  float64
#  7   driver_age          47777 non-null  float64
#  8   driver_race_raw     48009 non-null  object
#  9   driver_race         48009 non-null  object
#  10  violation_raw       48009 non-null  object
#  11  violation           48009 non-null  object
#  12  search_conducted    48009 non-null  object
#  13  search_type_raw     2012 non-null   object
#  14  search_type         2012 non-null   object
#  15  contraband_found    48009 non-null  bool
#  16  stop_outcome        48009 non-null  object
#  17  is_arrested         48009 non-null  bool
#  18  stop_duration       48009 non-null  object
#  19  out_of_state        47794 non-null  object
#  20  drugs_related_stop  48009 non-null  bool
#  21  district            48009 non-null  object
# dtypes: bool(3), float64(2), object(17)
# memory usage: 7.5+ MB

# %% [markdown]
# ## Combining object columns
#
# Currently, the date and time of each traffic stop are stored in separate object columns: ``stop_date`` and ``stop_time``.
#
# You'll combine these two columns into a single column, and then convert it to ``datetime`` format. This will enable convenient date-based attributes that we'll use later in the course.
#
# **INSTRUCTIONS**
#
# *    Use a string method to concatenate ``stop_date`` and ``stop_time`` (separated by a space), and store the result in ``combined``.
# *    Convert ``combined`` to ``datetime`` format, and store the result in a new column named ``stop_datetime``.
# *    Examine the ``DataFrame`` ``.dtypes`` to confirm that ``stop_datetime`` is a datetime column.

# %%
combined = ri.stop_date.str.cat(ri.stop_time, sep= ' ') # Concatenate 'stop_date' and 'stop_time' (separated by a space)

# %%
ri['stop_datetime'] = pd.to_datetime(combined) # # Convert 'combined' to datetime format

# %%
print(ri.dtypes)
# Out:
# id                            object
# stop_date                     object
# stop_time                     object
# location_raw                  object
# police_department             object
# driver_gender                 object
# driver_age_raw               float64
# driver_age                   float64
# driver_race_raw               object
# driver_race                   object
# violation_raw                 object
# violation                     object
# search_conducted              object
# search_type_raw               object
# search_type                   object
# contraband_found                bool
# stop_outcome                  object
# is_arrested                     bool
# stop_duration                 object
# out_of_state                  object
# drugs_related_stop              bool
# district                      object
# stop_datetime         datetime64[ns]
# dtype: object

# %%
pd.DataFrame(ri)
# Out:
#                    id state   stop_date stop_time location_raw  county_name  \
# 0       RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1       RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2       RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3       RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4       RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
# ...               ...   ...         ...       ...          ...          ...
# 509676       RI-NA-06    RI         NaN       NaN      Zone NA          NaN
# 509677       RI-NA-07    RI         NaN       NaN      Zone NA          NaN
# 509678       RI-NA-08    RI         NaN       NaN      Zone NA          NaN
# 509679       RI-NA-09    RI         NaN       NaN      Zone NA          NaN
# 509680       RI-NA-10    RI         NaN       NaN      Zone NA          NaN
#
#         county_fips  fine_grained_location police_department driver_gender  \
# 0               NaN                    NaN               600             M
# 1               NaN                    NaN               500             M
# 2               NaN                    NaN                 0           NaN
# 3               NaN                    NaN               500             M
# 4               NaN                    NaN               500             M
# ...             ...                    ...               ...           ...
# 509676          NaN                    NaN               NaN           NaN
# 509677          NaN                    NaN               NaN           NaN
# 509678          NaN                    NaN               NaN           NaN
# 509679          NaN                    NaN               NaN           NaN
# 509680          NaN                    NaN               NaN           NaN
#
#         ...  search_conducted  search_type_raw search_type contraband_found  \
# 0       ...             False              NaN         NaN            False
# 1       ...             False              NaN         NaN            False
# 2       ...             False              NaN         NaN            False
# 3       ...             False              NaN         NaN            False
# 4       ...             False              NaN         NaN            False
# ...     ...               ...              ...         ...              ...
# 509676  ...               NaN              NaN         NaN            False
# 509677  ...               NaN              NaN         NaN            False
# 509678  ...               NaN              NaN         NaN            False
# 509679  ...               NaN              NaN         NaN            False
# 509680  ...               NaN              NaN         NaN            False
#
#        stop_outcome is_arrested stop_duration out_of_state drugs_related_stop  \
# 0          Citation       False      0-15 Min        False              False
# 1          Citation       False     16-30 Min        False              False
# 2               NaN         NaN           NaN          NaN              False
# 3          Citation       False      0-15 Min        False              False
# 4          Citation       False      0-15 Min        False              False
# ...             ...         ...           ...          ...                ...
# 509676          NaN         NaN           NaN          NaN              False
# 509677          NaN         NaN           NaN          NaN              False
# 509678          NaN         NaN           NaN          NaN              False
# 509679          NaN         NaN           NaN          NaN              False
# 509680          NaN         NaN           NaN          NaN              False
#
#         district
# 0        Zone K1
# 1        Zone X4
# 2        Zone X1
# 3        Zone X4
# 4        Zone X4
# ...          ...
# 509676   Zone NA
# 509677   Zone NA
# 509678   Zone NA
# 509679   Zone NA
# 509680   Zone NA
#
# [509681 rows x 26 columns]

# %% [markdown]
# The last step that you'll take in this chapter is to set the ``stop_datetime`` column as the ``DataFrame``'s index. By replacing the default index with a ``DatetimeIndex``, you'll make it easier to analyze the dataset by date and time, which will come in handy later in the course.
#
# **INSTRUCTIONS**
#
# *   Set ``stop_datetime`` as the ``DataFrame`` index.
# *   Examine the index to verify that it is a ``DatetimeIndex``.
# *   Examine the ``DataFrame`` columns to confirm that ``stop_datetime`` is no longer one of the columns.

# %%
# Set 'stop_datetime' as the index
ri.set_index('stop_datetime', inplace=True)

# %%
print(ri.index) # # Examine the index
# Out:
# DatetimeIndex(['2005-01-02 20:30:00', '2005-01-04 12:55:00',
#                '2005-01-06 01:30:00', '2005-01-12 08:05:00',
#                '2005-01-18 08:15:00', '2005-01-18 17:13:00',
#                '2005-01-23 23:15:00', '2005-01-24 20:32:00',
#                '2005-02-09 03:05:00', '2005-02-11 01:20:00',
#                ...
#                '2006-08-08 22:22:00', '2006-08-08 22:25:00',
#                '2006-08-08 22:30:00', '2006-08-08 22:30:00',
#                '2006-08-08 22:45:00', '2006-08-08 22:45:00',
#                '2006-08-08 22:45:00', '2006-08-08 22:53:00',
#                '2006-08-08 23:00:00', '2006-08-08 23:00:00'],
#               dtype='datetime64[ns]', name='stop_datetime', length=48009, freq=None)

# %%
print(ri.columns) # Examine the columns
# Out:
# Index(['id', 'stop_date', 'stop_time', 'location_raw', 'police_department',
#        'driver_gender', 'driver_age_raw', 'driver_age', 'driver_race_raw',
#        'driver_race', 'violation_raw', 'violation', 'search_conducted',
#        'search_type_raw', 'search_type', 'contraband_found', 'stop_outcome',
#        'is_arrested', 'stop_duration', 'out_of_state', 'drugs_related_stop',
#        'district'],
#       dtype='object')

# %%
ri.head()
# Out:
#                                 id   stop_date stop_time location_raw  \
# stop_datetime
# 2005-01-02 20:30:00  RI-2005-00002  2005-01-02     20:30      Zone X4
# 2005-01-04 12:55:00  RI-2005-00004  2005-01-04     12:55      Zone X4
# 2005-01-06 01:30:00  RI-2005-00005  2005-01-06     01:30      Zone X4
# 2005-01-12 08:05:00  RI-2005-00006  2005-01-12     08:05      Zone X1
# 2005-01-18 08:15:00  RI-2005-00007  2005-01-18     08:15      Zone K3
#
#                     police_department driver_gender  driver_age_raw  \
# stop_datetime
# 2005-01-02 20:30:00               500             M          1987.0
# 2005-01-04 12:55:00               500             M          1986.0
# 2005-01-06 01:30:00               500             M          1978.0
# 2005-01-12 08:05:00                 0             M          1973.0
# 2005-01-18 08:15:00               300             M          1965.0
#
#                      driver_age driver_race_raw driver_race  ...  \
# stop_datetime                                                ...
# 2005-01-02 20:30:00        18.0               W       White  ...
# 2005-01-04 12:55:00        19.0               W       White  ...
# 2005-01-06 01:30:00        27.0               B       Black  ...
# 2005-01-12 08:05:00        32.0               B       Black  ...
# 2005-01-18 08:15:00        40.0               W       White  ...
#
#                     search_conducted search_type_raw search_type  \
# stop_datetime
# 2005-01-02 20:30:00            False             NaN         NaN
# 2005-01-04 12:55:00            False             NaN         NaN
# 2005-01-06 01:30:00            False             NaN         NaN
# 2005-01-12 08:05:00            False             NaN         NaN
# 2005-01-18 08:15:00            False             NaN         NaN
#
#                     contraband_found stop_outcome  is_arrested stop_duration  \
# stop_datetime
# 2005-01-02 20:30:00            False     Citation        False     16-30 Min
# 2005-01-04 12:55:00            False     Citation        False      0-15 Min
# 2005-01-06 01:30:00            False     Citation        False      0-15 Min
# 2005-01-12 08:05:00            False     Citation        False       30+ Min
# 2005-01-18 08:15:00            False     Citation        False      0-15 Min
#
#                      out_of_state drugs_related_stop district
# stop_datetime
# 2005-01-02 20:30:00         False              False  Zone X4
# 2005-01-04 12:55:00         False              False  Zone X4
# 2005-01-06 01:30:00         False              False  Zone X4
# 2005-01-12 08:05:00          True              False  Zone X1
# 2005-01-18 08:15:00          True              False  Zone K3
#
# [5 rows x 22 columns]

# %%
ri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509681 entries, 0 to 509680
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     509681 non-null  object
#  1   state                  509681 non-null  object
#  2   stop_date              509671 non-null  object
#  3   stop_time              509671 non-null  object
#  4   location_raw           509681 non-null  object
#  5   county_name            0 non-null       float64
#  6   county_fips            0 non-null       float64
#  7   fine_grained_location  0 non-null       float64
#  8   police_department      509671 non-null  object
#  9   driver_gender          480584 non-null  object
#  10  driver_age_raw         480632 non-null  float64
#  11  driver_age             478986 non-null  float64
#  12  driver_race_raw        480608 non-null  object
#  13  driver_race            480608 non-null  object
#  14  violation_raw          480608 non-null  object
#  15  violation              480608 non-null  object
#  16  search_conducted       509671 non-null  object
#  17  search_type_raw        17762 non-null   object
#  18  search_type            17762 non-null   object
#  19  contraband_found       509681 non-null  bool
#  20  stop_outcome           480608 non-null  object
#  21  is_arrested            480608 non-null  object
#  22  stop_duration          480608 non-null  object
#  23  out_of_state           479800 non-null  object
#  24  drugs_related_stop     509681 non-null  bool
#  25  district               509681 non-null  object
# dtypes: bool(2), float64(5), object(19)
# memory usage: 94.3+ MB

# %%
ri.describe()
# Out:
#        county_name  county_fips  fine_grained_location  driver_age_raw  \
# count          0.0          0.0                    0.0   480632.000000
# mean           NaN          NaN                    NaN     1970.509997
# std            NaN          NaN                    NaN      108.187159
# min            NaN          NaN                    NaN        0.000000
# 25%            NaN          NaN                    NaN     1967.000000
# 50%            NaN          NaN                    NaN     1980.000000
# 75%            NaN          NaN                    NaN     1987.000000
# max            NaN          NaN                    NaN     8801.000000
#
#           driver_age
# count  478986.000000
# mean       33.982027
# std        12.702864
# min        15.000000
# 25%        23.000000
# 50%        31.000000
# 75%        43.000000
# max        99.000000

# %%
pd.DataFrame(ri)
# Out:
#                    id state   stop_date stop_time location_raw  county_name  \
# 0       RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1       RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2       RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3       RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4       RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
# ...               ...   ...         ...       ...          ...          ...
# 509676       RI-NA-06    RI         NaN       NaN      Zone NA          NaN
# 509677       RI-NA-07    RI         NaN       NaN      Zone NA          NaN
# 509678       RI-NA-08    RI         NaN       NaN      Zone NA          NaN
# 509679       RI-NA-09    RI         NaN       NaN      Zone NA          NaN
# 509680       RI-NA-10    RI         NaN       NaN      Zone NA          NaN
#
#         county_fips  fine_grained_location police_department driver_gender  \
# 0               NaN                    NaN               600             M
# 1               NaN                    NaN               500             M
# 2               NaN                    NaN                 0           NaN
# 3               NaN                    NaN               500             M
# 4               NaN                    NaN               500             M
# ...             ...                    ...               ...           ...
# 509676          NaN                    NaN               NaN           NaN
# 509677          NaN                    NaN               NaN           NaN
# 509678          NaN                    NaN               NaN           NaN
# 509679          NaN                    NaN               NaN           NaN
# 509680          NaN                    NaN               NaN           NaN
#
#         ...  search_conducted  search_type_raw search_type contraband_found  \
# 0       ...             False              NaN         NaN            False
# 1       ...             False              NaN         NaN            False
# 2       ...             False              NaN         NaN            False
# 3       ...             False              NaN         NaN            False
# 4       ...             False              NaN         NaN            False
# ...     ...               ...              ...         ...              ...
# 509676  ...               NaN              NaN         NaN            False
# 509677  ...               NaN              NaN         NaN            False
# 509678  ...               NaN              NaN         NaN            False
# 509679  ...               NaN              NaN         NaN            False
# 509680  ...               NaN              NaN         NaN            False
#
#        stop_outcome is_arrested stop_duration out_of_state drugs_related_stop  \
# 0          Citation       False      0-15 Min        False              False
# 1          Citation       False     16-30 Min        False              False
# 2               NaN         NaN           NaN          NaN              False
# 3          Citation       False      0-15 Min        False              False
# 4          Citation       False      0-15 Min        False              False
# ...             ...         ...           ...          ...                ...
# 509676          NaN         NaN           NaN          NaN              False
# 509677          NaN         NaN           NaN          NaN              False
# 509678          NaN         NaN           NaN          NaN              False
# 509679          NaN         NaN           NaN          NaN              False
# 509680          NaN         NaN           NaN          NaN              False
#
#         district
# 0        Zone K1
# 1        Zone X4
# 2        Zone X1
# 3        Zone X4
# 4        Zone X4
# ...          ...
# 509676   Zone NA
# 509677   Zone NA
# 509678   Zone NA
# 509679   Zone NA
# 509680   Zone NA
#
# [509681 rows x 26 columns]

# %%
ri.isnull()
# Out:
#            id  state  stop_date  stop_time  location_raw  county_name  \
# 0       False  False      False      False         False         True
# 1       False  False      False      False         False         True
# 2       False  False      False      False         False         True
# 3       False  False      False      False         False         True
# 4       False  False      False      False         False         True
# ...       ...    ...        ...        ...           ...          ...
# 509676  False  False       True       True         False         True
# 509677  False  False       True       True         False         True
# 509678  False  False       True       True         False         True
# 509679  False  False       True       True         False         True
# 509680  False  False       True       True         False         True
#
#         county_fips  fine_grained_location  police_department  driver_gender  \
# 0              True                   True              False          False
# 1              True                   True              False          False
# 2              True                   True              False           True
# 3              True                   True              False          False
# 4              True                   True              False          False
# ...             ...                    ...                ...            ...
# 509676         True                   True               True           True
# 509677         True                   True               True           True
# 509678         True                   True               True           True
# 509679         True                   True               True           True
# 509680         True                   True               True           True
#
#         ...  search_conducted  search_type_raw  search_type  contraband_found  \
# 0       ...             False             True         True             False
# 1       ...             False             True         True             False
# 2       ...             False             True         True             False
# 3       ...             False             True         True             False
# 4       ...             False             True         True             False
# ...     ...               ...              ...          ...               ...
# 509676  ...              True             True         True             False
# 509677  ...              True             True         True             False
# 509678  ...              True             True         True             False
# 509679  ...              True             True         True             False
# 509680  ...              True             True         True             False
#
#         stop_outcome  is_arrested  stop_duration  out_of_state  \
# 0              False        False          False         False
# 1              False        False          False         False
# 2               True         True           True          True
# 3              False        False          False         False
# 4              False        False          False         False
# ...              ...          ...            ...           ...
# 509676          True         True           True          True
# 509677          True         True           True          True
# 509678          True         True           True          True
# 509679          True         True           True          True
# 509680          True         True           True          True
#
#         drugs_related_stop  district
# 0                    False     False
# 1                    False     False
# 2                    False     False
# 3                    False     False
# 4                    False     False
# ...                    ...       ...
# 509676               False     False
# 509677               False     False
# 509678               False     False
# 509679               False     False
# 509680               False     False
#
# [509681 rows x 26 columns]

# %%
ri.isnull().sum()
# Out:
# id                           0
# stop_date                    0
# stop_time                    0
# location_raw                 0
# county_fips              49999
# fine_grained_location    49999
# police_department            0
# driver_gender             1990
# driver_age_raw            1971
# driver_age                2208
# driver_race_raw           1988
# driver_race               1988
# violation_raw             1988
# violation                 1988
# search_conducted             0
# search_type_raw          47987
# search_type              47987
# contraband_found             0
# stop_outcome              1988
# is_arrested               1988
# stop_duration             1988
# out_of_state              2203
# drugs_related_stop           0
# district                     0
# dtype: int64

# %%
columns = ri.columns
columns
# Out:
# Index(['id,state,stop_date,stop_time,location_raw,county_name,county_fips,fine_grained_location,police_department,driver_gender,driver_age_raw,driver_age,driver_race_raw,driver_race,violation_raw,violation,search_conducted,search_type_raw,search_type,contraband_found,stop_outcome,is_arrested,stop_duration,out_of_state,drugs_related_stop,district'], dtype='object')

# %%
columns.split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-dc44d7694406> in <module>
# ----> 1 columns.split()
#
# AttributeError: 'Index' object has no attribute 'split'

# %%
ri1 = pd.read_csv("RI_cleaned.csv", delimiter = ";")

# %%
ri1
# Out:
#        id,state,stop_date,stop_time,location_raw,county_name,county_fips,fine_grained_location,police_department,driver_gender,driver_age_raw,driver_age,driver_race_raw,driver_race,violation_raw,violation,search_conducted,search_type_raw,search_type,contraband_found,stop_outcome,is_arrested,stop_duration,out_of_state,drugs_related_stop,district
# 0       RI-2005-00001,RI,2005-01-02,01:55,Zone K1,,,,6...
# 1       RI-2005-00002,RI,2005-01-02,20:30,Zone X4,,,,5...
# 2       RI-2005-00003,RI,2005-01-04,11:30,Zone X1,,,,0...
# 3       RI-2005-00004,RI,2005-01-04,12:55,Zone X4,,,,5...
# 4       RI-2005-00005,RI,2005-01-06,01:30,Zone X4,,,,5...
# ...                                                   ...
# 509676  RI-NA-06,RI,,,Zone NA,,,,,,,,,,,,,,,FALSE,,,,,...
# 509677  RI-NA-07,RI,,,Zone NA,,,,,,,,,,,,,,,FALSE,,,,,...
# 509678  RI-NA-08,RI,,,Zone NA,,,,,,,,,,,,,,,FALSE,,,,,...
# 509679  RI-NA-09,RI,,,Zone NA,,,,,,,,,,,,,,,FALSE,,,,,...
# 509680  RI-NA-10,RI,,,Zone NA,,,,,,,,,,,,,,,FALSE,,,,,...
#
# [509681 rows x 1 columns]

# %%
ri = pd.read_csv("police.csv", delimiter = ",")
# Out:
# C:\Users\Mustafa\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (8,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
ri.head(5)
# Out:
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# 2          NaN                    NaN                 0           NaN  ...
# 3          NaN                    NaN               500             M  ...
# 4          NaN                    NaN               500             M  ...
#
#    search_conducted  search_type_raw search_type contraband_found  \
# 0             False              NaN         NaN            False
# 1             False              NaN         NaN            False
# 2             False              NaN         NaN            False
# 3             False              NaN         NaN            False
# 4             False              NaN         NaN            False
#
#   stop_outcome is_arrested stop_duration out_of_state drugs_related_stop  \
# 0     Citation       False      0-15 Min        False              False
# 1     Citation       False     16-30 Min        False              False
# 2          NaN         NaN           NaN          NaN              False
# 3     Citation       False      0-15 Min        False              False
# 4     Citation       False      0-15 Min        False              False
#
#    district
# 0   Zone K1
# 1   Zone X4
# 2   Zone X1
# 3   Zone X4
# 4   Zone X4
#
# [5 rows x 26 columns]

# %%
ri = pd.read_csv("police.csv" , sep=',')
ri.head(5)
# Out:
# C:\Users\Mustafa\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (8,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# 2          NaN                    NaN                 0           NaN  ...
# 3          NaN                    NaN               500             M  ...
# 4          NaN                    NaN               500             M  ...
#
#    search_conducted  search_type_raw search_type contraband_found  \
# 0             False              NaN         NaN            False
# 1             False              NaN         NaN            False
# 2             False              NaN         NaN            False
# 3             False              NaN         NaN            False
# 4             False              NaN         NaN            False
#
#   stop_outcome is_arrested stop_duration out_of_state drugs_related_stop  \
# 0     Citation       False      0-15 Min        False              False
# 1     Citation       False     16-30 Min        False              False
# 2          NaN         NaN           NaN          NaN              False
# 3     Citation       False      0-15 Min        False              False
# 4     Citation       False      0-15 Min        False              False
#
#    district
# 0   Zone K1
# 1   Zone X4
# 2   Zone X1
# 3   Zone X4
# 4   Zone X4
#
# [5 rows x 26 columns]

# %%
ri.shape
# Out:
# (509681, 26)

# %%
ri=ri.iloc[1:50000] # iloc indexlerle calisir ilk 50 binlik satirla calisiyoruz.

# %%
ri["id"].count()
# Out:
# 49999

# %%
ri["id"]
# Out:
# 1        RI-2005-00002
# 2        RI-2005-00003
# 3        RI-2005-00004
# 4        RI-2005-00005
# 5        RI-2005-00006
#              ...
# 49995    RI-2006-35917
# 49996    RI-2006-35918
# 49997    RI-2006-35919
# 49998    RI-2006-35920
# 49999    RI-2006-35921
# Name: id, Length: 49999, dtype: object

# %%
ri["id"].describe()
# Out:
# count             49999
# unique            49999
# top       RI-2006-18083
# freq                  1
# Name: id, dtype: object

# %%
ri.describe()
# Out:
#        county_name  county_fips  fine_grained_location  driver_age_raw  \
# count          0.0          0.0                    0.0    48028.000000
# mean           NaN          NaN                    NaN     1965.183268
# std            NaN          NaN                    NaN      121.114603
# min            NaN          NaN                    NaN        0.000000
# 25%            NaN          NaN                    NaN     1964.000000
# 50%            NaN          NaN                    NaN     1976.000000
# 75%            NaN          NaN                    NaN     1983.000000
# max            NaN          NaN                    NaN     2006.000000
#
#          driver_age
# count  47791.000000
# mean      33.165408
# std       12.430172
# min       16.000000
# 25%       23.000000
# 50%       30.000000
# 75%       41.000000
# max       93.000000

# %%
ri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49999 entries, 1 to 49999
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     49999 non-null  object
#  1   state                  49999 non-null  object
#  2   stop_date              49999 non-null  object
#  3   stop_time              49999 non-null  object
#  4   location_raw           49999 non-null  object
#  5   county_name            0 non-null      float64
#  6   county_fips            0 non-null      float64
#  7   fine_grained_location  0 non-null      float64
#  8   police_department      49999 non-null  object
#  9   driver_gender          48009 non-null  object
#  10  driver_age_raw         48028 non-null  float64
#  11  driver_age             47791 non-null  float64
#  12  driver_race_raw        48011 non-null  object
#  13  driver_race            48011 non-null  object
#  14  violation_raw          48011 non-null  object
#  15  violation              48011 non-null  object
#  16  search_conducted       49999 non-null  object
#  17  search_type_raw        2012 non-null   object
#  18  search_type            2012 non-null   object
#  19  contraband_found       49999 non-null  bool
#  20  stop_outcome           48011 non-null  object
#  21  is_arrested            48011 non-null  object
#  22  stop_duration          48011 non-null  object
#  23  out_of_state           47796 non-null  object
#  24  drugs_related_stop     49999 non-null  bool
#  25  district               49999 non-null  object
# dtypes: bool(2), float64(5), object(19)
# memory usage: 9.3+ MB

# %%
ri.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     0 non-null      object
#  1   state                  0 non-null      object
#  2   stop_date              0 non-null      object
#  3   stop_time              0 non-null      object
#  4   location_raw           0 non-null      object
#  5   county_name            0 non-null      float64
#  6   county_fips            0 non-null      float64
#  7   fine_grained_location  0 non-null      float64
#  8   police_department      0 non-null      object
#  9   driver_gender          0 non-null      object
#  10  driver_age_raw         0 non-null      float64
#  11  driver_age             0 non-null      float64
#  12  driver_race_raw        0 non-null      object
#  13  driver_race            0 non-null      object
#  14  violation_raw          0 non-null      object
#  15  violation              0 non-null      object
#  16  search_conducted       0 non-null      object
#  17  search_type_raw        0 non-null      object
#  18  search_type            0 non-null      object
#  19  contraband_found       0 non-null      bool
#  20  stop_outcome           0 non-null      object
#  21  is_arrested            0 non-null      object
#  22  stop_duration          0 non-null      object
#  23  out_of_state           0 non-null      object
#  24  drugs_related_stop     0 non-null      bool
#  25  district               0 non-null      object
# dtypes: bool(2), float64(5), object(19)
# memory usage: 0.0+ bytes

# %%
ri.dropna() # bos olanlari dusuruyor, #bu direkt NaN bulunan İndex'i düşürür
# Out:
# Empty DataFrame
# Columns: [id, state, stop_date, stop_time, location_raw, county_name, county_fips, fine_grained_location, police_department, driver_gender, driver_age_raw, driver_age, driver_race_raw, driver_race, violation_raw, violation, search_conducted, search_type_raw, search_type, contraband_found, stop_outcome, is_arrested, stop_duration, out_of_state, drugs_related_stop, district]
# Index: []
#
# [0 rows x 26 columns]

# %%
ri
# Out:
#                   id state   stop_date stop_time location_raw  county_name  \
# 1      RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2      RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3      RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4      RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
# 5      RI-2005-00006    RI  2005-01-12     08:05      Zone X1          NaN
# ...              ...   ...         ...       ...          ...          ...
# 49995  RI-2006-35917    RI  2006-08-08     22:45      Zone K3          NaN
# 49996  RI-2006-35918    RI  2006-08-08     22:45      Zone K3          NaN
# 49997  RI-2006-35919    RI  2006-08-08     22:53      Zone X4          NaN
# 49998  RI-2006-35920    RI  2006-08-08     23:00      Zone K1          NaN
# 49999  RI-2006-35921    RI  2006-08-08     23:00      Zone K3          NaN
#
#        county_fips  fine_grained_location police_department driver_gender  \
# 1              NaN                    NaN               500             M
# 2              NaN                    NaN                 0           NaN
# 3              NaN                    NaN               500             M
# 4              NaN                    NaN               500             M
# 5              NaN                    NaN                 0             M
# ...            ...                    ...               ...           ...
# 49995          NaN                    NaN               300             M
# 49996          NaN                    NaN               300             F
# 49997          NaN                    NaN               500             M
# 49998          NaN                    NaN               600             F
# 49999          NaN                    NaN               300             M
#
#        ...  search_conducted  search_type_raw search_type contraband_found  \
# 1      ...             False              NaN         NaN            False
# 2      ...             False              NaN         NaN            False
# 3      ...             False              NaN         NaN            False
# 4      ...             False              NaN         NaN            False
# 5      ...             False              NaN         NaN            False
# ...    ...               ...              ...         ...              ...
# 49995  ...             False              NaN         NaN            False
# 49996  ...             False              NaN         NaN            False
# 49997  ...             False              NaN         NaN            False
# 49998  ...             False              NaN         NaN            False
# 49999  ...             False              NaN         NaN            False
#
#       stop_outcome is_arrested stop_duration out_of_state drugs_related_stop  \
# 1         Citation       False     16-30 Min        False              False
# 2              NaN         NaN           NaN          NaN              False
# 3         Citation       False      0-15 Min        False              False
# 4         Citation       False      0-15 Min        False              False
# 5         Citation       False       30+ Min         True              False
# ...            ...         ...           ...          ...                ...
# 49995     Citation       False      0-15 Min        False              False
# 49996     Citation       False      0-15 Min         True              False
# 49997     Citation       False     16-30 Min         True              False
# 49998     Citation       False      0-15 Min        False              False
# 49999     Citation       False     16-30 Min        False              False
#
#        district
# 1       Zone X4
# 2       Zone X1
# 3       Zone X4
# 4       Zone X4
# 5       Zone X1
# ...         ...
# 49995   Zone K3
# 49996   Zone K3
# 49997   Zone X4
# 49998   Zone K1
# 49999   Zone K3
#
# [49999 rows x 26 columns]

# %%
ri["state"]
# Out:
# 1        RI
# 2        RI
# 3        RI
# 4        RI
# 5        RI
#          ..
# 49995    RI
# 49996    RI
# 49997    RI
# 49998    RI
# 49999    RI
# Name: state, Length: 49999, dtype: object

# %%
ri.shape
# Out:
# (49999, 26)

# %%
ri.drop(["state", "county_name"], axis = 1)
# Out:
#                   id   stop_date stop_time location_raw  county_fips  \
# 1      RI-2005-00002  2005-01-02     20:30      Zone X4          NaN
# 2      RI-2005-00003  2005-01-04     11:30      Zone X1          NaN
# 3      RI-2005-00004  2005-01-04     12:55      Zone X4          NaN
# 4      RI-2005-00005  2005-01-06     01:30      Zone X4          NaN
# 5      RI-2005-00006  2005-01-12     08:05      Zone X1          NaN
# ...              ...         ...       ...          ...          ...
# 49995  RI-2006-35917  2006-08-08     22:45      Zone K3          NaN
# 49996  RI-2006-35918  2006-08-08     22:45      Zone K3          NaN
# 49997  RI-2006-35919  2006-08-08     22:53      Zone X4          NaN
# 49998  RI-2006-35920  2006-08-08     23:00      Zone K1          NaN
# 49999  RI-2006-35921  2006-08-08     23:00      Zone K3          NaN
#
#        fine_grained_location police_department driver_gender  driver_age_raw  \
# 1                        NaN               500             M          1987.0
# 2                        NaN                 0           NaN             NaN
# 3                        NaN               500             M          1986.0
# 4                        NaN               500             M          1978.0
# 5                        NaN                 0             M          1973.0
# ...                      ...               ...           ...             ...
# 49995                    NaN               300             M          1973.0
# 49996                    NaN               300             F          1971.0
# 49997                    NaN               500             M          1952.0
# 49998                    NaN               600             F          1982.0
# 49999                    NaN               300             M          1965.0
#
#        driver_age  ... search_conducted search_type_raw search_type  \
# 1            18.0  ...            False             NaN         NaN
# 2             NaN  ...            False             NaN         NaN
# 3            19.0  ...            False             NaN         NaN
# 4            27.0  ...            False             NaN         NaN
# 5            32.0  ...            False             NaN         NaN
# ...           ...  ...              ...             ...         ...
# 49995        33.0  ...            False             NaN         NaN
# 49996        35.0  ...            False             NaN         NaN
# 49997        54.0  ...            False             NaN         NaN
# 49998        24.0  ...            False             NaN         NaN
# 49999        41.0  ...            False             NaN         NaN
#
#       contraband_found stop_outcome is_arrested stop_duration  out_of_state  \
# 1                False     Citation       False     16-30 Min         False
# 2                False          NaN         NaN           NaN           NaN
# 3                False     Citation       False      0-15 Min         False
# 4                False     Citation       False      0-15 Min         False
# 5                False     Citation       False       30+ Min          True
# ...                ...          ...         ...           ...           ...
# 49995            False     Citation       False      0-15 Min         False
# 49996            False     Citation       False      0-15 Min          True
# 49997            False     Citation       False     16-30 Min          True
# 49998            False     Citation       False      0-15 Min         False
# 49999            False     Citation       False     16-30 Min         False
#
#       drugs_related_stop district
# 1                  False  Zone X4
# 2                  False  Zone X1
# 3                  False  Zone X4
# 4                  False  Zone X4
# 5                  False  Zone X1
# ...                  ...      ...
# 49995              False  Zone K3
# 49996              False  Zone K3
# 49997              False  Zone X4
# 49998              False  Zone K1
# 49999              False  Zone K3
#
# [49999 rows x 24 columns]

# %%
ri.shape
# Out:
# (49999, 26)

# %%
ri.drop(["state", "county_name"], axis = 1, inplace = True)

# %%
ri.shape
# Out:
# (49999, 24)

# %%
ri.columns
# Out:
# Index(['id', 'state', 'stop_date', 'stop_time', 'location_raw', 'county_name',
#        'county_fips', 'fine_grained_location', 'police_department',
#        'driver_gender', 'driver_age_raw', 'driver_age', 'driver_race_raw',
#        'driver_race', 'violation_raw', 'violation', 'search_conducted',
#        'search_type_raw', 'search_type', 'contraband_found', 'stop_outcome',
#        'is_arrested', 'stop_duration', 'out_of_state', 'drugs_related_stop',
#        'district'],
#       dtype='object')

# %%
for i in ri.columns:
    print(i)
# Out:
# id
# stop_date
# stop_time
# location_raw
# county_fips
# fine_grained_location
# police_department
# driver_gender
# driver_age_raw
# driver_age
# driver_race_raw
# driver_race
# violation_raw
# violation
# search_conducted
# search_type_raw
# search_type
# contraband_found
# stop_outcome
# is_arrested
# stop_duration
# out_of_state
# drugs_related_stop
# district

# %%
ri.dtypes
# Out:
# id                        object
# state                     object
# stop_date                 object
# stop_time                 object
# location_raw              object
# county_name              float64
# county_fips              float64
# fine_grained_location    float64
# police_department         object
# driver_gender             object
# driver_age_raw           float64
# driver_age               float64
# driver_race_raw           object
# driver_race               object
# violation_raw             object
# violation                 object
# search_conducted          object
# search_type_raw           object
# search_type               object
# contraband_found            bool
# stop_outcome              object
# is_arrested               object
# stop_duration             object
# out_of_state              object
# drugs_related_stop          bool
# district                  object
# dtype: object

# %%
ri.isnull().sum() # bos olan satirlarda bosluk sayisi
# Out:
# id                           0
# state                        0
# stop_date                    0
# stop_time                    0
# location_raw                 0
# county_name              49999
# county_fips              49999
# fine_grained_location    49999
# police_department            0
# driver_gender             1990
# driver_age_raw            1971
# driver_age                2208
# driver_race_raw           1988
# driver_race               1988
# violation_raw             1988
# violation                 1988
# search_conducted             0
# search_type_raw          47987
# search_type              47987
# contraband_found             0
# stop_outcome              1988
# is_arrested               1988
# stop_duration             1988
# out_of_state              2203
# drugs_related_stop           0
# district                     0
# dtype: int64

# %%
fixed_df = pd.read_csv('bikes.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
fixed_df[:3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-cea08426973e> in <module>
# ----> 1 df["indirme"] = df["indirme"].str.replace("+","")
#
# NameError: name 'df' is not defined

# %%
s = pd.Series(["A_Str_Series"])
s.str.split("_")
0    [A, Str, Series]
dtype: object
# Out:
# <>:3: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# <>:3: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# <ipython-input-38-76d2b0352371>:3: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   0    [A, Str, Series]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-76d2b0352371> in <module>
#       1 s = pd.Series(["A_Str_Series"])
#       2 s.str.split("_")
# ----> 3 0    [A, Str, Series]
#       4 dtype: object
#
# NameError: name 'A' is not defined

# %%
# Out:
# [0, 12, 45.21, 34, 99.91]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-35f1bac3605a> in <module>
# ----> 1 celcius = np.array()
#
# TypeError: array() missing required argument 'object' (pos 1)
