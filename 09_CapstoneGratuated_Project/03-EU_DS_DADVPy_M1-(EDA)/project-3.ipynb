# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.warn("this will not show")

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_info_columns', 500)
pd.set_option('display.max_info_rows', 2000)
pd.set_option('display.expand_frame_repr', True)
pd.set_option('display.width', 2000)

# %%
pwd
# Out:
# 'C:\\Users\\Mustafa\\Desktop\\MyWorkSpace\\Github_Data_Science\\09_CapstoneGratuated_Project\\03-EU_DS_DADVPy_M1-(EDA)'

# %%
df = pd.read_json('scout_car.json', orient = "records" , lines=True )

# %%
df.head(3)
# Out:
#                                                                                                                                                 url make_model                                   short_description body_type  price               vat         km registration         prev_owner  kW      hp                                     Type Previous Owners                        Next Inspection         Inspection new                          Warranty Full Service Non-smoking Vehicle null      Make         Model     Offer Number First Registration       Body Color      Paint Type           Body Color Original          Upholstery              Body Nr. of Doors Nr. of Seats      Model Code         Gearing Type    Displacement Cylinders          Weight  Drive chain                                   Fuel                                                               Consumption               CO2 Emission Emission Class                                                                                                                                                                                                                                                                                                     \nComfort & Convenience\n                                                  \nEntertainment & Media\n                                                    \nExtras\n                                                                                                                                                                                                                                                                                 \nSafety & Security\n  \
# 0         https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-xenon-navi-klima-diesel-black-bdab349a-caa5-41b0-98eb-c1345b84445e    Audi A1         Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770    VAT deductible  56,013 km      01/2016  2 previous owners NaN   66 kW  [, Used, , Diesel (Particulate Filter)]           \n2\n  [\n06/2021\n, \n99 g CO2/km (comb)\n]  [\nYes\n, \nEuro 6\n]           [\n, \n, \n4 (Green)\n]     [\n, \n]            [\n, \n]   []  \nAudi\n  [\n, A1, \n]  [\nLR-062483\n]     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]           [\nMythosschwarz\n]  [\nCloth, Black\n]  [\n, Sedans, \n]      [\n5\n]      [\n5\n]  [\n0588/BDF\n]  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]  [\n1,220 kg\n]  [\nfront\n]  [\n, Diesel (Particulate Filter), \n]  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)], [3.5 l/100 km (country)]]   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]  [Air conditioning, Armrest, Automatic climate control, Cruise control, Electrical side mirrors, Hill Holder, Leather steering wheel, Light sensor, Multi-function steering wheel, Navigation system, Park Distance Control, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Start-stop system]                [Bluetooth, Hands-free equipment, On-board computer, Radio]            [Alloy wheels, Catalytic Converter, Voice Control]                                          [ABS, Central door lock, Daytime running lights, Driver-side airbag, Electronic stability control, Fog lights, Immobilizer, Isofix, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control, Xenon headlights]
# 1                                      https://www.autoscout24.com//offers/audi-a1-1-8-tfsi-sport-gasoline-red-b2547f8a-e83f-6237-e053-e250040a56df    Audi A1                                      1.8 TFSI sport    Sedans  14500  Price negotiable  80,000 km      03/2017               None NaN  141 kW                     [, Used, , Gasoline]             NaN                                    NaN                    NaN                               NaN          NaN                 NaN   []  \nAudi\n  [\n, A1, \n]              NaN     [\n, 2017, \n]    [\n, Red, \n]             NaN                           NaN   [\nCloth, Grey\n]  [\n, Sedans, \n]      [\n3\n]      [\n4\n]  [\n0588/BCY\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]  [\n1,255 kg\n]  [\nfront\n]                     [\n, Gasoline, \n]  [[5.6 l/100 km (comb)], [7.1 l/100 km (city)], [4.7 l/100 km (country)]]  [\n129 g CO2/km (comb)\n]   [\nEuro 6\n]                                                                                                                                      [Air conditioning, Automatic climate control, Hill Holder, Leather steering wheel, Lumbar support, Parking assist system sensors rear, Power windows, Start-stop system, Tinted windows]  [Bluetooth, Hands-free equipment, On-board computer, Radio, Sound system]  [Alloy wheels, Sport seats, Sport suspension, Voice Control]  [ABS, Central door lock, Central door lock with remote control, Daytime running lights, Driver-side airbag, Electronic stability control, Head airbag, Immobilizer, Isofix, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control, Xenon headlights]
# 2  https://www.autoscout24.com//offers/audi-a1-sportback-1-6-tdi-s-tronic-einparkhilfe-plus-music-diesel-black-6183cb6a-8570-4b86-a132-9b54214bca88    Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+music    Sedans  14640    VAT deductible  83,450 km      02/2016   1 previous owner NaN   85 kW  [, Used, , Diesel (Particulate Filter)]           \n1\n                                    NaN                    NaN  [\n, \n, \n99 g CO2/km (comb)\n]          NaN                 NaN   []  \nAudi\n  [\n, A1, \n]   [\nAM-95365\n]     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]  [\nmythosschwarz metallic\n]  [\nCloth, Black\n]  [\n, Sedans, \n]      [\n4\n]      [\n4\n]             NaN  [\n, Automatic, \n]  [\n1,598 cc\n]       NaN             NaN  [\nfront\n]  [\n, Diesel (Particulate Filter), \n]  [[3.8 l/100 km (comb)], [4.4 l/100 km (city)], [3.4 l/100 km (country)]]   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]                            [Air conditioning, Cruise control, Electrical side mirrors, Hill Holder, Leather steering wheel, Multi-function steering wheel, Navigation system, Park Distance Control, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Seat heating, Start-stop system]                                                   [MP3, On-board computer]                                 [Alloy wheels, Voice Control]                                                                        [ABS, Central door lock, Daytime running lights, Driver-side airbag, Electronic stability control, Immobilizer, Isofix, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            description   Emission Label    Gears Country version Electricity consumption Last Service Date Other Fuel Types Availability Last Timing Belt Service Date Available from
# 0  [\n, Sicherheit:,  , Deaktivierung für Beifahrer-Airbag,  , ESC mit elektronischer Quersperre,  , Tagfahrlicht,  , Reifendruck-Kontrollanzeige,  , Kopfairbag-System mit Seiten-Airbags vorn,  , Sicherheitslenksäule, Assistenzsysteme:,  , Berganfahrassistent, Komfort:,  , Scheinwerferreinigung,  , Xenon plus inklusive Scheinwerfer-Reinigungsanlage,  , Scheinwerfer-Reinigungsanlage,  , Einparkhilfe hinten,  , Licht-/Regensensor,  , Funkfernbedienung,  , Elektrische Luftzusatzheizung, Interieur:...              NaN      NaN             NaN                     NaN               NaN              NaN          NaN                           NaN            NaN
# 1                                                                                                                                                                                                                                                                                                                                                                                                         [\nLangstreckenfahrzeug daher die hohe Kilometerleistung. , Bremsen neu bei 62000 km. , Gut gepflegter A1\n]  [\n4 (Green)\n]  [\n7\n]             NaN                     NaN               NaN              NaN          NaN                           NaN            NaN
# 2  [\n, Fahrzeug-Nummer: AM-95365,  , Ehem. UPE 24.640 EUR,  , Komfort,  , Klimaanlage,  , Elektrische Fensterheber,  , Sitzheizung,  , Tempomat,  , Zentralverriegelung,  , Leder-Lenkrad,  , Elektrische Spiegel,  , Wärmedämmendes Glas,  , Anfahrassistent,  , Sicherheit,  , Window/Kopfairbags,  , ESP (el. Stabilitäts Programm),  , Elektronische Wegfahrsperre,  , Reifendruckkontrolle,  , Tagfahrlicht,  , Exterieur,  , Alufelgen 16 Zoll,  , Einparkhilfe vo + hi,  , Interieur,  , Stoff Zeitgeist,  ...  [\n4 (Green)\n]      NaN             NaN                     NaN               NaN              NaN          NaN                           NaN            NaN

# %%
df.dtypes
# Out:
# url                               object
# make_model                        object
# short_description                 object
# body_type                         object
# price                              int64
# vat                               object
# km                                object
# registration                      object
# prev_owner                        object
# kW                               float64
# hp                                object
# Type                              object
# Previous Owners                   object
# Next Inspection                   object
# Inspection new                    object
# Warranty                          object
# Full Service                      object
# Non-smoking Vehicle               object
# null                              object
# Make                              object
# Model                             object
# Offer Number                      object
# First Registration                object
# Body Color                        object
# Paint Type                        object
# Body Color Original               object
# Upholstery                        object
# Body                              object
# Nr. of Doors                      object
# Nr. of Seats                      object
# Model Code                        object
# Gearing Type                      object
# Displacement                      object
# Cylinders                         object
# Weight                            object
# Drive chain                       object
# Fuel                              object
# Consumption                       object
# CO2 Emission                      object
# Emission Class                    object
# \nComfort & Convenience\n         object
# \nEntertainment & Media\n         object
# \nExtras\n                        object
# \nSafety & Security\n             object
# description                       object
# Emission Label                    object
# Gears                             object
# Country version                   object
# Electricity consumption           object
# Last Service Date                 object
# Other Fuel Types                  object
# Availability                      object
# Last Timing Belt Service Date     object
# Available from                    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   url                            object
#  1   make_model                     object
#  2   short_description              object
#  3   body_type                      object
#  4   price                          int64
#  5   vat                            object
#  6   km                             object
#  7   registration                   object
#  8   prev_owner                     object
#  9   kW                             float64
#  10  hp                             object
#  11  Type                           object
#  12  Previous Owners                object
#  13  Next Inspection                object
#  14  Inspection new                 object
#  15  Warranty                       object
#  16  Full Service                   object
#  17  Non-smoking Vehicle            object
#  18  null                           object
#  19  Make                           object
#  20  Model                          object
#  21  Offer Number                   object
#  22  First Registration             object
#  23  Body Color                     object
#  24  Paint Type                     object
#  25  Body Color Original            object
#  26  Upholstery                     object
#  27  Body                           object
#  28  Nr. of Doors                   object
#  29  Nr. of Seats                   object
#  30  Model Code                     object
#  31  Gearing Type                   object
#  32  Displacement                   object
#  33  Cylinders                      object
#  34  Weight                         object
#  35  Drive chain                    object
#  36  Fuel                           object
#  37  Consumption                    object
#  38  CO2 Emission                   object
#  39  Emission Class                 object
#  40
# Comfort & Convenience
#         object
#  41
# Entertainment & Media
#         object
#  42
# Extras
#                        object
#  43
# Safety & Security
#             object
#  44  description                    object
#  45  Emission Label                 object
#  46  Gears                          object
#  47  Country version                object
#  48  Electricity consumption        object
#  49  Last Service Date              object
#  50  Other Fuel Types               object
#  51  Availability                   object
#  52  Last Timing Belt Service Date  object
#  53  Available from                 object
# dtypes: float64(1), int64(1), object(52)
# memory usage: 6.6+ MB

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat', 'km', 'registration', 'prev_owner', 'kW', 'hp', 'Type', 'Previous Owners', 'Next Inspection', 'Inspection new', 'Warranty', 'Full Service', 'Non-smoking Vehicle', 'null', 'Make', 'Model', 'Offer Number', 'First Registration', 'Body Color', 'Paint Type', 'Body Color Original', 'Upholstery', 'Body', 'Nr. of Doors', 'Nr. of Seats', 'Model Code', 'Gearing Type', 'Displacement', 'Cylinders', 'Weight', 'Drive chain', 'Fuel', 'Consumption', 'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n', '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n', 'description', 'Emission Label', 'Gears', 'Country version', 'Electricity consumption', 'Last Service Date', 'Other Fuel Types', 'Availability', 'Last Timing Belt Service Date', 'Available from'], dtype='object')

# %%
df.make_model[:2]
# Out:
# 0    Audi A1
# 1    Audi A1
# Name: make_model, dtype: object

# %%
df.describe(include="all")
# Out:
#                                                                                                                                        url make_model                  short_description body_type         price             vat     km registration        prev_owner   kW     hp                                     Type Previous Owners Next Inspection         Inspection new              Warranty             Full Service Non-smoking Vehicle   null      Make         Model   Offer Number First Registration       Body Color      Paint Type Body Color Original          Upholstery              Body Nr. of Doors Nr. of Seats      Model Code      Gearing Type    Displacement Cylinders          Weight  Drive chain                                   Fuel                                                               Consumption               CO2 Emission Emission Class                                                \nComfort & Convenience\n                                         \nEntertainment & Media\n      \nExtras\n                                                                                                                                                                                                                       \nSafety & Security\n description   Emission Label    Gears Country version    Electricity consumption          Last Service Date Other Fuel Types                  Availability Last Timing Belt Service Date Available from
# count                                                                                                                                15919      15919                              15873     15859  15919.000000           11406  15919        15919              9091  0.0  15919                                    15917            9279            3535                   3932                 10499                     8215                7177  15919     15919         15919          12744              14322            15322           10147               12160               12199             15859        15707        14942            4978             15919           15423     10239            8945         9061                                  15919                                                                     14013                      14111          12898                                                                    14999                                                             14545           12957                                                                                                                                                                                                                                       14937       15919             3985    11207            7586                        137                        566              880                           635                            16            272
# unique                                                                                                                               15919          9                              10001         9           NaN               2   6690           48                 4  NaN     81                                      169             102            1399                    202                   515                      122                  94      1         3             9          11440                  4               14               3                1927                  46                 9            6            6             232                 3              77         7             434            3                                     77                                                                       881                        123              7                                                                     6198                                                               346             659                                                                                                                                                                                                                                        4443       12874                6       10              23                          1                        266                1                            15                            15             46
# top     https://www.autoscout24.com//offers/audi-a3-sportback-30-tdi-sitzheizung-tempomat-diesel-grey-cb3e3b96-5b59-4cab-acc9-4fafc7ad7990    Audi A3  SPB 1.6 TDI 116 CV S tronic Sport    Sedans           NaN  VAT deductible  10 km          -/-  1 previous owner  NaN  85 kW  [, Used, , Diesel (Particulate Filter)]           \n1\n     \n04/2022\n  [\nYes\n, \nEuro 6\n]  [\n, \n, \nEuro 6\n]  [\n, \n, \n4 (Green)\n]            [\n, \n]     []  \nOpel\n  [\n, A3, \n]  [\nTA76392\n]     [\n, 2018, \n]  [\n, Black, \n]  [\nMetallic\n]  [\nOnyx Schwarz\n]  [\nCloth, Black\n]  [\n, Sedans, \n]      [\n5\n]      [\n5\n]  [\n0035/BCB\n]  [\n, Manual, \n]  [\n1,598 cc\n]   [\n4\n]  [\n1,163 kg\n]  [\nfront\n]  [\n, Diesel (Particulate Filter), \n]  [[3.9 l/100 km (comb)], [4.1 l/100 km (city)], [3.7 l/100 km (country)]]  [\n120 g CO2/km (comb)\n]   [\nEuro 6\n]  [Air conditioning, Electrical side mirrors, Hill Holder, Power windows]  [Bluetooth, Hands-free equipment, On-board computer, Radio, USB]  [Alloy wheels]  [ABS, Central door lock, Daytime running lights, Driver-side airbag, Electronic stability control, Fog lights, Immobilizer, Isofix, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control]          []  [\n4 (Green)\n]  [\n6\n]   [\nGermany\n]  [\n0 kWh/100 km (comb)\n]  [\n02/2019\n, \nEuro 6\n]     [[], [], []]  \nin 90 days from ordering\n                 [\n04/2016\n]   \n31/08/19\n
# freq                                                                                                                                     1       3097                                 64      7903           NaN           10980   1045         1597              8294  NaN   2542                                     3475            8101              62                    523                  1868                     2235                3647  15919      7343          3097             27               4522             3745            9794                 338                5821              7903        11575        13336             268              8153            4761      8105             574         8886                                   4315                                                                       304                        740          10139                                                                      216                                                              1282            3245                                                                                                                                                                                                                                         538         636             3553     5822            4502                        137                         23              880                           196                             2             98
# mean                                                                                                                                   NaN        NaN                                NaN       NaN  18019.896727             NaN    NaN          NaN               NaN  NaN    NaN                                      NaN             NaN             NaN                    NaN                   NaN                      NaN                 NaN    NaN       NaN           NaN            NaN                NaN              NaN             NaN                 NaN                 NaN               NaN          NaN          NaN             NaN               NaN             NaN       NaN             NaN          NaN                                    NaN                                                                       NaN                        NaN            NaN                                                                      NaN                                                               NaN             NaN                                                                                                                                                                                                                                         NaN         NaN              NaN      NaN             NaN                        NaN                        NaN              NaN                           NaN                           NaN            NaN
# std                                                                                                                                    NaN        NaN                                NaN       NaN   7386.169409             NaN    NaN          NaN               NaN  NaN    NaN                                      NaN             NaN             NaN                    NaN                   NaN                      NaN                 NaN    NaN       NaN           NaN            NaN                NaN              NaN             NaN                 NaN                 NaN               NaN          NaN          NaN             NaN               NaN             NaN       NaN             NaN          NaN                                    NaN                                                                       NaN                        NaN            NaN                                                                      NaN                                                               NaN             NaN                                                                                                                                                                                                                                         NaN         NaN              NaN      NaN             NaN                        NaN                        NaN              NaN                           NaN                           NaN            NaN
# min                                                                                                                                    NaN        NaN                                NaN       NaN     13.000000             NaN    NaN          NaN               NaN  NaN    NaN                                      NaN             NaN             NaN                    NaN                   NaN                      NaN                 NaN    NaN       NaN           NaN            NaN                NaN              NaN             NaN                 NaN                 NaN               NaN          NaN          NaN             NaN               NaN             NaN       NaN             NaN          NaN                                    NaN                                                                       NaN                        NaN            NaN                                                                      NaN                                                               NaN             NaN                                                                                                                                                                                                                                         NaN         NaN              NaN      NaN             NaN                        NaN                        NaN              NaN                           NaN                           NaN            NaN
# 25%                                                                                                                                    NaN        NaN                                NaN       NaN  12850.000000             NaN    NaN          NaN               NaN  NaN    NaN                                      NaN             NaN             NaN                    NaN                   NaN                      NaN                 NaN    NaN       NaN           NaN            NaN                NaN              NaN             NaN                 NaN                 NaN               NaN          NaN          NaN             NaN               NaN             NaN       NaN             NaN          NaN                                    NaN                                                                       NaN                        NaN            NaN                                                                      NaN                                                               NaN             NaN                                                                                                                                                                                                                                         NaN         NaN              NaN      NaN             NaN                        NaN                        NaN              NaN                           NaN                           NaN            NaN
# 50%                                                                                                                                    NaN        NaN                                NaN       NaN  16900.000000             NaN    NaN          NaN               NaN  NaN    NaN                                      NaN             NaN             NaN                    NaN                   NaN                      NaN                 NaN    NaN       NaN           NaN            NaN                NaN              NaN             NaN                 NaN                 NaN               NaN          NaN          NaN             NaN               NaN             NaN       NaN             NaN          NaN                                    NaN                                                                       NaN                        NaN            NaN                                                                      NaN                                                               NaN             NaN                                                                                                                                                                                                                                         NaN         NaN              NaN      NaN             NaN                        NaN                        NaN              NaN                           NaN                           NaN            NaN
# 75%                                                                                                                                    NaN        NaN                                NaN       NaN  21900.000000             NaN    NaN          NaN               NaN  NaN    NaN                                      NaN             NaN             NaN                    NaN                   NaN                      NaN                 NaN    NaN       NaN           NaN            NaN                NaN              NaN             NaN                 NaN                 NaN               NaN          NaN          NaN             NaN               NaN             NaN       NaN             NaN          NaN                                    NaN                                                                       NaN                        NaN            NaN                                                                      NaN                                                               NaN             NaN                                                                                                                                                                                                                                         NaN         NaN              NaN      NaN             NaN                        NaN                        NaN              NaN                           NaN                           NaN            NaN
# max                                                                                                                                    NaN        NaN                                NaN       NaN  74600.000000             NaN    NaN          NaN               NaN  NaN    NaN                                      NaN             NaN             NaN                    NaN                   NaN                      NaN                 NaN    NaN       NaN           NaN            NaN                NaN              NaN             NaN                 NaN                 NaN               NaN          NaN          NaN             NaN               NaN             NaN       NaN             NaN          NaN                                    NaN                                                                       NaN                        NaN            NaN                                                                      NaN                                                               NaN             NaN                                                                                                                                                                                                                                         NaN         NaN              NaN      NaN             NaN                        NaN                        NaN              NaN                           NaN                           NaN            NaN

# %%
df.describe()
# Out:
#               price   kW
# count  15919.000000  0.0
# mean   18019.896727  NaN
# std     7386.169409  NaN
# min       13.000000  NaN
# 25%    12850.000000  NaN
# 50%    16900.000000  NaN
# 75%    21900.000000  NaN
# max    74600.000000  NaN

# %%
df.shape
# Out:
# (15919, 54)

# %%
[df.columns]
# Out:
# [Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat', 'km', 'registration', 'prev_owner', 'kW', 'hp', 'Type', 'Previous Owners', 'Next Inspection', 'Inspection new', 'Warranty', 'Full Service', 'Non-smoking Vehicle', 'null', 'Make', 'Model', 'Offer Number', 'First Registration', 'Body Color', 'Paint Type', 'Body Color Original', 'Upholstery', 'Body', 'Nr. of Doors', 'Nr. of Seats', 'Model Code', 'Gearing Type', 'Displacement', 'Cylinders', 'Weight', 'Drive chain', 'Fuel', 'Consumption', 'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n', '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n', 'description', 'Emission Label', 'Gears', 'Country version', 'Electricity consumption', 'Last Service Date', 'Other Fuel Types', 'Availability', 'Last Timing Belt Service Date', 'Available from'], dtype='object')]

# %%
df['\nEntertainment & Media\n'].unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-af039396d09b> in <module>
# ----> 1 df['\nEntertainment & Media\n'].unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in unique(self)
#    1814         Categories (3, object): [a < b < c]
#    1815         """
# -> 1816         result = super().unique()
#    1817         return result
#    1818
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in unique(self)
#    1244             result = values.unique()
#    1245         else:
# -> 1246             result = unique1d(values)
#    1247
#    1248         return result
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in unique(values)
#     380
#     381     table = htable(len(values))
# --> 382     uniques = table.unique(values)
#     383     uniques = _reconstruct_data(uniques, original.dtype, original)
#     384     return uniques
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
df.rename(columns={'\nEntertainment & Media\n':"Entertainment & Media"}, inplace=True)
df.head(0)
# Out:
# Empty DataFrame
# Columns: [url, make_model, short_description, body_type, price, vat, km, registration, prev_owner, kW, hp, Type, Previous Owners, Next Inspection, Inspection new, Warranty, Full Service, Non-smoking Vehicle, null, Make, Model, Offer Number, First Registration, Body Color, Paint Type, Body Color Original, Upholstery, Body, Nr. of Doors, Nr. of Seats, Model Code, Gearing Type, Displacement, Cylinders, Weight, Drive chain, Fuel, Consumption, CO2 Emission, Emission Class,
# Comfort & Convenience
# , Entertainment & Media,
# Extras
# ,
# Safety & Security
# , description, Emission Label, Gears, Country version, Electricity consumption, Last Service Date, Other Fuel Types, Availability, Last Timing Belt Service Date, Available from]
# Index: []

# %%
[df.columns]
# Out:
# [Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat', 'km', 'registration', 'prev_owner', 'kW', 'hp', 'Type', 'Previous Owners', 'Next Inspection', 'Inspection new', 'Warranty', 'Full Service', 'Non-smoking Vehicle', 'null', 'Make', 'Model', 'Offer Number', 'First Registration', 'Body Color', 'Paint Type', 'Body Color Original', 'Upholstery', 'Body', 'Nr. of Doors', 'Nr. of Seats', 'Model Code', 'Gearing Type', 'Displacement', 'Cylinders', 'Weight', 'Drive chain', 'Fuel', 'Consumption', 'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n', 'Entertainment & Media', '\nExtras\n', '\nSafety & Security\n', 'description', 'Emission Label', 'Gears', 'Country version', 'Electricity consumption', 'Last Service Date', 'Other Fuel Types', 'Availability', 'Last Timing Belt Service Date', 'Available from'], dtype='object')]

# %%
df['Entertainment & Media'][0]
# Out:
# ['Bluetooth', 'Hands-free equipment', 'On-board computer', 'Radio']

# %%
df['Entertainment & Media'][:]
# Out:
# 0                                           [Bluetooth, Hands-free equipment, On-board computer, Radio]
# 1                             [Bluetooth, Hands-free equipment, On-board computer, Radio, Sound system]
# 2                                                                              [MP3, On-board computer]
# 3        [Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB]
# 4                      [Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, USB]
#                                                       ...
# 15914                   [Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, USB]
# 15915                                      [Bluetooth, Digital radio, Hands-free equipment, Radio, USB]
# 15916                                       [Bluetooth, Hands-free equipment, On-board computer, Radio]
# 15917                                                            [Bluetooth, Digital radio, Radio, USB]
# 15918                                                                                             [USB]
# Name: Entertainment & Media, Length: 15919, dtype: object

# %%
df['short_description'].unique()
# Out:
# array(['Sportback 1.4 TDI S-tronic Xenon Navi Klima', '1.8 TFSI sport',
#        'Sportback 1.6 TDI S tronic Einparkhilfe plus+music', ...,
#        'ELYSEE ENERGY dCi 160 EDC',
#        'INITIALE Paris TCe 225 EDC GPF ACC EU6',
#        'TCe 225 EDC GPF LIM Deluxe Pano,RFK'], dtype=object)

# %%
df['Entertainment & Media'].unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-f1d7df041657> in <module>
# ----> 1 df['Entertainment & Media'].unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in unique(self)
#    1814         Categories (3, object): [a < b < c]
#    1815         """
# -> 1816         result = super().unique()
#    1817         return result
#    1818
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in unique(self)
#    1244             result = values.unique()
#    1245         else:
# -> 1246             result = unique1d(values)
#    1247
#    1248         return result
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in unique(values)
#     380
#     381     table = htable(len(values))
# --> 382     uniques = table.unique(values)
#     383     uniques = _reconstruct_data(uniques, original.dtype, original)
#     384     return uniques
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
type(df['Offer Number'])
# Out:
# pandas.core.series.Series

# %%
df['make_model'][0]
# Out:
# 'Audi A1'

# %%
df.null.value_counts()
# Out:
# []    15919
# Name: null, dtype: int64

# %%
df.body_type.value_counts()
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
df.\nExtras\n.value_counts()
# Out:
#   File "<ipython-input-23-5504e712693f>", line 1
#     df.\nExtras\n.value_counts()
#                                 ^
# SyntaxError: unexpected character after line continuation character

# %%
df.make_model[:].unique()
# Out:
# array(['Audi A1', 'Audi A2', 'Audi A3', 'Opel Astra', 'Opel Corsa',
#        'Opel Insignia', 'Renault Clio', 'Renault Duster',
#        'Renault Espace'], dtype=object)

# %%
df["make_model"].unique()
# Out:
# array(['Audi A1', 'Audi A2', 'Audi A3', 'Opel Astra', 'Opel Corsa',
#        'Opel Insignia', 'Renault Clio', 'Renault Duster',
#        'Renault Espace'], dtype=object)

# %%
df["\nExtras\n"].unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-05b32f9b83ed> in <module>
# ----> 1 df["\nExtras\n"].unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in unique(self)
#    1814         Categories (3, object): [a < b < c]
#    1815         """
# -> 1816         result = super().unique()
#    1817         return result
#    1818
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in unique(self)
#    1244             result = values.unique()
#    1245         else:
# -> 1246             result = unique1d(values)
#    1247
#    1248         return result
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in unique(values)
#     380
#     381     table = htable(len(values))
# --> 382     uniques = table.unique(values)
#     383     uniques = _reconstruct_data(uniques, original.dtype, original)
#     384     return uniques
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
df['make_model'].nunique()
# Out:
# 9

# %%
df['make_model'].value_counts()
# Out:
# Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2526
# Opel Corsa        2219
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: make_model, dtype: int64

# %%
df['make_model'].mode()
# Out:
# 0    Audi A3
# dtype: object

# %%
df['body_type'].mode()
# Out:
# 0    Sedans
# dtype: object

# %%
df['make_model'].nunique()
# Out:
# 9

# %%
df.groupby('make_model', "body_type") # ["body_type"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-252fec37b9f9> in <module>
# ----> 1 df.groupby('make_model', "body_type") # ["body_type"]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5797         if level is None and by is None:
#    5798             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 5799         axis = self._get_axis_number(axis)
#    5800
#    5801         return groupby_generic.DataFrameGroupBy(
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     405             except KeyError:
#     406                 pass
# --> 407         raise ValueError(f"No axis named {axis} for object type {cls}")
#     408
#     409     @classmethod
#
# ValueError: No axis named body_type for object type <class 'pandas.core.frame.DataFrame'>

# %%
df[(df['make_model'] == "Audi A3")] # make_model de "Audi A3" icerenleri getirdik.
# Out:
#                                                                                                                                                   url make_model                                short_description      body_type  price               vat          km registration        prev_owner  kW      hp                                     Type Previous Owners                         Next Inspection                      Inspection new                                  Warranty                Full Service                Non-smoking Vehicle null      Make         Model    Offer Number First Registration        Body Color      Paint Type           Body Color Original                 Upholstery                     Body Nr. of Doors Nr. of Seats      Model Code         Gearing Type    Displacement Cylinders          Weight  Drive chain                                   Fuel                                                               Consumption               CO2 Emission      Emission Class                                                                                                                                                                                                                                                                                                                                                                                                                           \nComfort & Convenience\n                                                                                          Entertainment & Media                                                    \nExtras\n  \
# 2615               https://www.autoscout24.com//offers/audi-a3-1-5-tfsi-benzina-turbo-155-cv-cabrio-gasoline-red-fed48347-14c1-463a-ad50-13290be1e168    Audi A3             1,5 TFSI BENZINA TURBO 155 CV CABRIO    Convertible  10893    VAT deductible   19,800 km      06/2018              None NaN  110 kW                     [, Used, , Gasoline]             NaN                                     NaN                                 NaN  [\n16 months\n, \n116 g CO2/km (comb)\n]  [\n, \n, \nEuro 6d-TEMP\n]                           [\n, \n]   []  \nAudi\n  [\n, A3, \n]             NaN     [\n, 2018, \n]     [\n, Red, \n]             NaN                   [\nRosso\n]  [\nPart leather, Brown\n]    [\n, Convertible, \n]      [\n2\n]      [\n4\n]             NaN  [\n, Automatic, \n]  [\n1,498 cc\n]   [\n4\n]  [\n1,470 kg\n]  [\nfront\n]                     [\n, Gasoline, \n]  [[5.1 l/100 km (comb)], [6.3 l/100 km (city)], [4.4 l/100 km (country)]]  [\n116 g CO2/km (comb)\n]  [\nEuro 6d-TEMP\n]                                                                                                                                [Air conditioning, Armrest, Automatic climate control, Cruise control, Leather steering wheel, Light sensor, Multi-function steering wheel, Navigation system, Park Distance Control, Parking assist system camera, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Sunroof]  [Bluetooth, CD player, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB]                                 [Alloy wheels, Shift paddles]
# 2616                            https://www.autoscout24.com//offers/audi-a3-1-6-tdi-s-tronic-design-diesel-white-1c24851b-7253-4578-84e3-0cebfc14048f    Audi A3                          1.6 TDI S tronic design         Sedans  13000  Price negotiable   36,792 km      06/2017  1 previous owner NaN   81 kW                       [, Used, , Diesel]           \n1\n                                     NaN                                 NaN                                       NaN                         NaN                                NaN   []  \nAudi\n  [\n, A3, \n]             NaN     [\n, 2017, \n]   [\n, White, \n]             NaN                           NaN                        NaN         [\n, Sedans, \n]      [\n3\n]      [\n5\n]             NaN  [\n, Automatic, \n]  [\n1,598 cc\n]   [\n4\n]  [\n1,255 kg\n]          NaN                       [\n, Diesel, \n]    [[4 l/100 km (comb)], [4.7 l/100 km (city)], [3.6 l/100 km (country)]]  [\n107 g CO2/km (comb)\n]        [\nEuro 6\n]                                                                                                                                                                                                                                                                                                                            [Air conditioning, Hill Holder, Leather steering wheel, Multi-function steering wheel, Power windows, Start-stop system]                                                          [Bluetooth, CD player, MP3, On-board computer, Radio]                                 [Alloy wheels, Voice Control]
# 2617                 https://www.autoscout24.com//offers/audi-a3-sportback-1-6-tdi-s-tronic-business-diesel-blue-eded146b-1833-46bc-bae9-58676dc64769    Audi A3              SPORTBACK 1.6 TDI S tronic Business         Sedans  15450    VAT deductible  149,006 km      10/2016  1 previous owner NaN   81 kW                       [, Used, , Diesel]           \n1\n                                     NaN                                 NaN                                       NaN                         NaN                                NaN   []  \nAudi\n  [\n, A3, \n]   [\n2753381\n]     [\n, 2016, \n]    [\n, Blue, \n]  [\nMetallic\n]                     [\nBlu\n]                 [\nGrey\n]         [\n, Sedans, \n]          NaN          NaN             NaN  [\n, Automatic, \n]             NaN       NaN             NaN          NaN                       [\n, Diesel, \n]                                                                       NaN                        NaN        [[], [], []]                                                                                                                                                                                                                                                                                                                                                                                                                                                 NaN                                                                                                            NaN                                                           NaN
# 2618                 https://www.autoscout24.com//offers/audi-a3-sportback-2-0-tdi-leder-navi-xenon-diesel-black-afcb8517-d261-49ed-918a-0b04b891ef69    Audi A3              Sportback 2.0 TDI Leder Navi Xenon+         Sedans  15680    VAT deductible  141,147 km      02/2016  1 previous owner NaN  110 kW  [, Used, , Diesel (Particulate Filter)]           \n1\n                                     NaN                                 NaN                                       NaN     [\n, \n, \n4 (Green)\n]                                NaN   []  \nAudi\n  [\n, A3, \n]    [\n224098\n]     [\n, 2016, \n]   [\n, Black, \n]  [\nMetallic\n]      [\nmythosschwarz met.\n]      [\nalcantara, Grey\n]         [\n, Sedans, \n]      [\n4\n]      [\n5\n]  [\n0588/AWJ\n]  [\n, Automatic, \n]  [\n1,968 cc\n]       NaN             NaN          NaN  [\n, Diesel (Particulate Filter), \n]                                                                       NaN                        NaN        [[], [], []]                                                                                                                                               [Air conditioning, Automatic climate control, Cruise control, Electrical side mirrors, Multi-function steering wheel, Navigation system, Park Distance Control, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Start-stop system]                                                                      [Bluetooth, CD player, On-board computer]                        [Alloy wheels, Roof rack, Sport seats]
# 2619        https://www.autoscout24.com//offers/audi-a3-2-0tdi-s-tronic-navi-mmi-bixenon-led-sensori-diesel-grey-8d3b33ae-84c3-4f32-bfe6-6e3c522e50f6    Audi A3    2.0TDI/S tronic/NAVI/MMI/BIXENON//LED/SENSORI         Sedans  16490  Price negotiable   44,500 km      08/2016  1 previous owner NaN  110 kW                       [, Used, , Diesel]           \n1\n                                     NaN                                 NaN                           [\n12 months\n]                    [\n, \n]                                NaN   []  \nAudi\n  [\n, A3, \n]             NaN     [\n, 2016, \n]    [\n, Grey, \n]  [\nMetallic\n]                           NaN                        NaN         [\n, Sedans, \n]      [\n5\n]          NaN             NaN  [\n, Automatic, \n]             NaN       NaN             NaN          NaN                       [\n, Diesel, \n]                                                                       NaN                        NaN                 NaN  [Air conditioning, Armrest, Automatic climate control, Cruise control, Electrically adjustable seats, Electrical side mirrors, Hill Holder, Leather steering wheel, Light sensor, Lumbar support, Multi-function steering wheel, Navigation system, Park Distance Control, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Split rear seats, Start-stop system, Tinted windows]  [Bluetooth, CD player, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB]               [Alloy wheels, Roof rack, Ski bag, Sport seats]
# ...                                                                                                                                               ...        ...                                              ...            ...    ...               ...         ...          ...               ...  ..     ...                                      ...             ...                                     ...                                 ...                                       ...                         ...                                ...  ...       ...           ...             ...                ...               ...             ...                           ...                        ...                      ...          ...          ...             ...                  ...             ...       ...             ...          ...                                    ...                                                                       ...                        ...                 ...                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...                                                                                                            ...                                                           ...
# 5707                                https://www.autoscout24.com//offers/audi-a3-spb-30-tfsi-sport-gasoline-white-9c14fff3-1270-4a37-b528-97541d487624    Audi A3                                SPB 30 TFSI Sport         Sedans  25000    VAT deductible       54 km      01/2019              None NaN   85 kW           [, Pre-registered, , Super 95]             NaN                                     NaN                                 NaN                                        \n                         NaN  [\n, \n, \n117 g CO2/km (comb)\n]   []  \nAudi\n  [\n, A3, \n]  [\njkbzqkr4\n]     [\n, 2019, \n]   [\n, White, \n]             NaN                           NaN         [\nCloth, Other\n]         [\n, Sedans, \n]      [\n5\n]      [\n5\n]             NaN     [\n, Manual, \n]    [\n999 cc\n]   [\n3\n]             NaN  [\nfront\n]                     [\n, Super 95, \n]    [[5.1 l/100 km (comb)], [6 l/100 km (city)], [4.6 l/100 km (country)]]  [\n117 g CO2/km (comb)\n]                 NaN                                                                                                                                       [Air conditioning, Armrest, Automatic climate control, Cruise control, Leather steering wheel, Light sensor, Multi-function steering wheel, Navigation system, Park Distance Control, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Start-stop system]                                    [Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio]  [Alloy wheels, Sport seats, Sport suspension, Voice Control]
# 5708         https://www.autoscout24.com//offers/audi-a3-sportback-35-tfsi-1-5-150-ps-euro-6-wltp-gasoline-white-d84d9ed1-c735-48a1-89ba-d614f7da6a0a    Audi A3    Sportback, 35 TFSI, 1.5, 150 PS, EURO 6, WLTP         Sedans  24980    VAT deductible       50 km      01/2019  1 previous owner NaN  110 kW       [, Pre-registered, , Super E10 95]           \n1\n                                     NaN  [\nYes\n, \n125 g CO2/km (comb)\n]                                       NaN                         NaN                                NaN   []  \nAudi\n  [\n, A3, \n]      [\n3097\n]     [\n, 2019, \n]   [\n, White, \n]             NaN                [\nIbisweiß\n]                [\nCloth\n]         [\n, Sedans, \n]      [\n5\n]      [\n5\n]  [\n0588/BLL\n]     [\n, Manual, \n]  [\n1,498 cc\n]   [\n4\n]  [\n1,325 kg\n]          NaN                 [\n, Super E10 95, \n]  [[5.5 l/100 km (comb)], [6.9 l/100 km (city)], [4.7 l/100 km (country)]]  [\n125 g CO2/km (comb)\n]                 NaN                                                                                                                                                                   [Air conditioning, Armrest, Automatic climate control, Electrical side mirrors, Multi-function steering wheel, Navigation system, Park Distance Control, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Seat heating, Start-stop system]                                                                                               [Bluetooth, USB]                                                [Alloy wheels]
# 5709  https://www.autoscout24.com//offers/audi-a3-sportback-design-30-tfsi-sitzheizung-vorne-lic-gasoline-silver-db9a12ca-43b9-4e01-9569-1f08bad2ca8a    Audi A3  Sportback design 30 TFSI Sitzheizung vorne, Lic  Station wagon  24980              None    6,666 km      02/2019  1 previous owner NaN   85 kW            [, Demonstration, , Super 95]           \n1\n  [\n02/2022\n, \n118 g CO2/km (comb)\n]                                 NaN                      [\n, \n, \nEuro 6\n]                         NaN            [\n, \n, \n4 (Green)\n]   []  \nAudi\n  [\n, A3, \n]   [\nA001496\n]     [\n, 2019, \n]  [\n, Silver, \n]  [\nMetallic\n]           [\nFlorettsilber\n]  [\nPart leather, Black\n]  [\n, Station wagon, \n]      [\n5\n]      [\n5\n]  [\n0588/BHX\n]     [\n, Manual, \n]    [\n999 cc\n]       NaN  [\n1,365 kg\n]          NaN                     [\n, Super 95, \n]  [[5.1 l/100 km (comb)], [6.1 l/100 km (city)], [4.6 l/100 km (country)]]  [\n118 g CO2/km (comb)\n]        [\nEuro 6\n]                                                                                                                                                        [Air conditioning, Armrest, Automatic climate control, Cruise control, Electrical side mirrors, Leather steering wheel, Light sensor, Multi-function steering wheel, Park Distance Control, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Start-stop system]                                          [Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, USB]                                     [Alloy wheels, Roof rack]
# 5710   https://www.autoscout24.com//offers/audi-a3-sportback-30-tfsi-design-connectivity-einpark-gasoline-silver-f06bd9a0-25f5-49ae-bb6f-5342e6aa26db    Audi A3    Sportback 30 TFSI design Connectivity Einpark         Sedans  24980    VAT deductible       10 km          -/-              None NaN   85 kW                      [, New, , Super 95]             NaN                                     NaN                                 NaN                                        \n                         NaN  [\n, \n, \n113 g CO2/km (comb)\n]   []  \nAudi\n  [\n, A3, \n]    [\nGDR658\n]                NaN  [\n, Silver, \n]  [\nMetallic\n]  [\nFlorettsilber Metallic\n]  [\nPart leather, Black\n]         [\n, Sedans, \n]      [\n4\n]      [\n5\n]  [\n0588/BHX\n]     [\n, Manual, \n]    [\n999 cc\n]   [\n3\n]  [\n1,255 kg\n]          NaN                     [\n, Super 95, \n]  [[4.8 l/100 km (comb)], [5.8 l/100 km (city)], [4.2 l/100 km (country)]]  [\n113 g CO2/km (comb)\n]        [\nEuro 6\n]                                                                                                                                                        [Air conditioning, Armrest, Automatic climate control, Cruise control, Electrical side mirrors, Leather steering wheel, Light sensor, Multi-function steering wheel, Park Distance Control, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Start-stop system]                                           [Bluetooth, CD player, Hands-free equipment, On-board computer, USB]                                     [Alloy wheels, Roof rack]
# 5711   https://www.autoscout24.com//offers/audi-a3-sportback-30-tfsi-design-connectivity-einpark-gasoline-silver-4a7f6963-67d7-4225-b290-4fa31dc5c4c5    Audi A3    Sportback 30 TFSI DESIGN Connectivity Einpark         Sedans  24980    VAT deductible       10 km          -/-              None NaN   85 kW                      [, New, , Super 95]             NaN                                     NaN                                 NaN                                        \n                         NaN  [\n, \n, \n113 g CO2/km (comb)\n]   []  \nAudi\n  [\n, A3, \n]    [\nGDR657\n]                NaN  [\n, Silver, \n]  [\nMetallic\n]  [\nFlorettsilber Metallic\n]  [\nPart leather, Black\n]         [\n, Sedans, \n]      [\n4\n]      [\n5\n]  [\n0588/BHX\n]     [\n, Manual, \n]    [\n999 cc\n]   [\n3\n]  [\n1,255 kg\n]          NaN                     [\n, Super 95, \n]  [[4.8 l/100 km (comb)], [5.8 l/100 km (city)], [4.2 l/100 km (country)]]  [\n113 g CO2/km (comb)\n]        [\nEuro 6\n]                                                                                                                                                        [Air conditioning, Armrest, Automatic climate control, Cruise control, Electrical side mirrors, Leather steering wheel, Light sensor, Multi-function steering wheel, Park Distance Control, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Start-stop system]                                           [Bluetooth, CD player, Hands-free equipment, On-board computer, USB]                                     [Alloy wheels, Roof rack]
#
#                                                                                                                                                                                                                                                                                                                                                                                                 \nSafety & Security\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          description        Emission Label    Gears Country version Electricity consumption Last Service Date Other Fuel Types Availability Last Timing Belt Service Date Available from
# 2615                  [ABS, Adaptive Cruise Control, Blind spot monitor, Central door lock, Central door lock with remote control, Daytime running lights, Driver-side airbag, Electronic stability control, Emergency brake assistant, Fog lights, Immobilizer, LED Daytime Running Lights, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control, Xenon headlights]  [\n, Attenzione il prezzo che vedete e' indicativo in quanto la macchina ha un subentro leasing WV interamente detraibile, 10598 euro, che e' l'anticipo del leasing. Comunque se volete potete pagarla......e' costata 56,500 euro non e' una a3 normale.... E un auto che sta bene a montecarlo come vedete (era una delle piu' guardate durante il GP di Montecarlo...)e non sfigura neanche di fianco alla GT2 di Valentino (foto il giorno della consegna...)........ leggete bene qui sotto :, ......CERTO...                   NaN  [\n7\n]     [\nItaly\n]                     NaN       \n06/2019\n              NaN          NaN                           NaN            NaN
# 2616                                                                                                                                            [ABS, Central door lock with remote control, Driver-side airbag, Electronic stability control, Fog lights, Head airbag, Immobilizer, Isofix, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control, Xenon headlights]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   []                   NaN  [\n7\n]             NaN                     NaN               NaN              NaN          NaN                           NaN            NaN
# 2617                                                                                                                                                                                                                                                                                                                                                                                                              NaN  [\nDEK:[2753381], Codice riferimento: 16061 - Per maggiori informazioni, accessori e foto su questa auto chiamaci al numero 0687811764. IVA deducibile da ogni professionista. La qualita' delle nostre auto e' garantita, ogni auto possiede una carta d'identita', certezza del chilometraggio, unico proprietario, tutte le manutenzioni effettuate, assenza di danni strutturali, garanzia estendibile fino a 36 mesi. Finanziamenti personalizzati e Ritiro dell'usato. Questa auto e' lontana da casa tua?...                   NaN      NaN             NaN                     NaN               NaN              NaN          NaN                           NaN            NaN
# 2618                                                                                                                                                                                                                                             [ABS, Central door lock, Driver-side airbag, Electronic stability control, Fog lights, Immobilizer, Isofix, Passenger-side airbag, Power steering, Xenon headlights]  [\n, Nr. 2908 Standort: 27404 Bockel ,  ,  ,  Sonderausstattung: ,  , Audi music interface , Audiosystem (CD/Radio) , Bluetooth-Schnittstelle , Dachreling (Aluminium) , Einparkhilfe hinten , Einparkhilfe vorne , Geschwindigkeits-Regelanlage (Tempomat) , Getriebe 6-Gang - Doppelkupplungsgetriebe S-tronic , Komfort-Klimaautomatik 2-Zonen , Lendenwirbelstützen vorn, elektr. verstellbar , Lenkrad (Sport/Leder) mit Multifunktion , Mittelarmlehne vorn , Multimedia (DVD-Laufwerk und 2 SD-Karten-Slo...       [\n4 (Green)\n]      NaN             NaN                     NaN               NaN              NaN          NaN                           NaN            NaN
# 2619  [ABS, Adaptive Cruise Control, Adaptive headlights, Alarm system, Central door lock with remote control, Daytime running lights, Driver-side airbag, Electronic stability control, Fog lights, Head airbag, Immobilizer, Isofix, Lane departure warning system, LED Daytime Running Lights, LED Headlights, Passenger-side airbag, Rear airbag, Side airbag, Tire pressure monitoring system, Xenon headlights]  [\n(SI ACCETTANO EVENTUALI PERMUTE) GARANZIA COME PER LEGGE. KM CERTIFICATI E TUTTI TAGLIANDATI AUDI. AUTOVETTURA COME NUOVA NESSUN GRAFFIO DA VETRINA. L' AUTO E DISPONIBILE PER QUALSIASI PROVA E/O TEST ANCHE IN OFFICINE AUTORIZZATE AUDI. ACCESSORI: , SISTEMA DI NAVIGAZIONE MMI PLUS CON MMI TOUCH , CON MAPPE EUROPA IN 3D, FARI BI-XENON LENTICOLARI E DIREZIONALI CON LAVA-FARI A PRESSIONE, LUCI DIURNI A LED, CAMBIO AUTOMATICO S-TRONIC, ECO START/STOP, SENSORI DI PARCHEGGIO ANTERIORI E POSTERIO...                   NaN      NaN     [\nItaly\n]                     NaN               NaN              NaN          NaN                           NaN            NaN
# ...                                                                                                                                                                                                                                                                                                                                                                                                               ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...                   ...      ...             ...                     ...               ...              ...          ...                           ...            ...
# 5707                                                                                                                                                       [ABS, Adaptive headlights, Central door lock, Daytime running lights, Driver-side airbag, Emergency brake assistant, Fog lights, Isofix, LED Daytime Running Lights, LED Headlights, Passenger-side airbag, Power steering, Side airbag, Traction control]  [\nGaranzia del costruttore , vettura aziendale, in pronta consegna , per informazioni contattare Gerardo Campitelli al 0585 836111,  , Audi Extended Warranty: 2 anni, fino a 80.000 km,  , Colori carrozzeria: Bianco Ibis (T9), Nero brillante (A2),  , Martinetto,  , Pacchetto Business plus,  , Pacchetto di navigazione,  , Pacchetto Evolution Plus/ combinaz.,  , Pacchetto nero titanio - Audi exclusive/ con WDE,  , Proiettori a LED,  , Ruota di scorta minispare da 18",  , Sensore pioggia/luci c...  [\n1 (No sticker)\n]  [\n6\n]             NaN                     NaN               NaN              NaN          NaN                           NaN            NaN
# 5708                                                                                                                                                                                                                                                                                                     [ABS, Central door lock, Driver-side airbag, Electronic stability control, Power steering, Xenon headlights]  [\nWir heißen Sie herzlich Willkommen im Autohaus Biggel! Bereits seit 1880 sind wir in Kressbronn ansässig und beraten Sie gerne bei Ihrer Suche nach einem neuen Fahrzeug. , Übrigens: Über 15.000 Fahrzeuge finden Sie im Zentrallager unter http://www.autohaus-biggel.de !, Die unverbindliche Preisempfehlung des Herstellers bei diesem Fahrzeug liegt bei 32.766 Euro. Daraus ergibt sich für Sie eine Ersparnis von 7.786 Euro (-23 %) ggü. der UVP! , Innenraum und Komfort, :, 5-Sitzer, Elektrische ...       [\n4 (Green)\n]  [\n6\n]             NaN                     NaN               NaN              NaN          NaN                           NaN            NaN
# 5709                                                                                                                                                                 [ABS, Central door lock, Daytime running lights, Driver-side airbag, Electronic stability control, Immobilizer, Isofix, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control, Xenon headlights]  [\n, Ausstattungspakete:,  Connectivity paket, Nichtraucherpaket, Assistenzsysteme:,  Einparkhilfe hinten, Licht und Sicht:,  Tagfahrlicht, Audio & Kommunikation:,  Multi-Funktions-Display, AUX & USB Anschluss, Räder und Reifen:,  Leichtmetallfelgen 17 Zoll, Komfort:,  Fahrer-/Beifahrersitz höhenverstellbar, Armauflage Fahrer/Beifahrer, Servotronic, Zentralver. mit Fernbedienung, Fensterheber elektrisch 2-fach, Interieur:,  Sitze Teilleder, Innenfarbe schwarz, Multifunktions-Lederlenkrad: 3 ...                   NaN      NaN             NaN                     NaN               NaN              NaN          NaN                           NaN            NaN
# 5710                                                                                                                                                                 [ABS, Central door lock, Daytime running lights, Driver-side airbag, Electronic stability control, Immobilizer, Isofix, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control, Xenon headlights]  [\n, Preis inkl. Überführungskosten, Getriebe / Antrieb, Frontantrieb, Schaltgetriebe, Pakete, Connectivity Paket, Airbags, Fahrer-/Beifahrerairbag, Knieairbag, Kopfairbag, Seitenairbag, Sicherheit, Xenon plus, Tagfahrlicht, Allwetterlicht, Einparkhilfe, Elektrisches Stabilitätsprogramm ESP, ISOFIX Kindersitzbefestigung, Kindersicherung, Lichtsensor, Regensensor, Reifendruckkontrolle, top tether Kindersitzverankerung hinten, Bremsbelagverschleißkontrolle, Audio & Kommunikation, MMI Radio, Na...       [\n4 (Green)\n]  [\n6\n]   [\nGermany\n]                     NaN               NaN              NaN          NaN                           NaN            NaN
# 5711                                                                                                                                                                 [ABS, Central door lock, Daytime running lights, Driver-side airbag, Electronic stability control, Immobilizer, Isofix, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control, Xenon headlights]  [\n, Preis inkl. Überführungskosten, Getriebe / Antrieb, Frontantrieb, Schaltgetriebe, Pakete, Connectivity Paket, Airbags, Fahrer-/Beifahrerairbag, Knieairbag, Kopfairbag, Seitenairbag, Sicherheit, Xenon plus, Tagfahrlicht, Allwetterlicht, Einparkhilfe, Elektrisches Stabilitätsprogramm ESP, ISOFIX Kindersitzbefestigung, Kindersicherung, Lichtsensor, Regensensor, Reifendruckkontrolle, top tether Kindersitzverankerung hinten, Bremsbelagverschleißkontrolle, Audio & Kommunikation, MMI Radio, Na...       [\n4 (Green)\n]  [\n6\n]   [\nGermany\n]                     NaN               NaN              NaN          NaN                           NaN            NaN
#
# [3097 rows x 54 columns]

# %%
df['make_model'].hist(bins=25)

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='make_model', data=df, order = df['make_model'].value_counts().index)

# %%
fig, ax = plt.subplots(figsize=(12, 7))
df.boxplot (column = 'price')

# %%
fig, ax = plt.subplots(figsize=(15, 7))
sns.boxplot(x="make_model", y="price", data=df,  width= 0.8 ) # hue = "body_type"

# %%
#df.info()

# %%
# df = df.dropna(how = 'all', axis=1)

# %%
df.describe()
# Out:
#               price   kW
# count  15919.000000  0.0
# mean   18019.896727  NaN
# std     7386.169409  NaN
# min       13.000000  NaN
# 25%    12850.000000  NaN
# 50%    16900.000000  NaN
# 75%    21900.000000  NaN
# max    74600.000000  NaN

# %%
df.describe().T
# Out:
#          count          mean          std   min      25%      50%      75%      max
# price  15919.0  18019.896727  7386.169409  13.0  12850.0  16900.0  21900.0  74600.0
# kW         0.0           NaN          NaN   NaN      NaN      NaN      NaN      NaN

# %%
df.shape
# Out:
# (15919, 54)

# %%
df.isna().sum()
# Out:
# url                                  0
# make_model                           0
# short_description                   46
# body_type                           60
# price                                0
# vat                               4513
# km                                   0
# registration                         0
# prev_owner                        6828
# kW                               15919
# hp                                   0
# Type                                 2
# Previous Owners                   6640
# Next Inspection                  12384
# Inspection new                   11987
# Warranty                          5420
# Full Service                      7704
# Non-smoking Vehicle               8742
# null                                 0
# Make                                 0
# Model                                0
# Offer Number                      3175
# First Registration                1597
# Body Color                         597
# Paint Type                        5772
# Body Color Original               3759
# Upholstery                        3720
# Body                                60
# Nr. of Doors                       212
# Nr. of Seats                       977
# Model Code                       10941
# Gearing Type                         0
# Displacement                       496
# Cylinders                         5680
# Weight                            6974
# Drive chain                       6858
# Fuel                                 0
# Consumption                       1906
# CO2 Emission                      1808
# Emission Class                    3021
# \nComfort & Convenience\n          920
# Entertainment & Media             1374
# \nExtras\n                        2962
# \nSafety & Security\n              982
# description                          0
# Emission Label                   11934
# Gears                             4712
# Country version                   8333
# Electricity consumption          15782
# Last Service Date                15353
# Other Fuel Types                 15039
# Availability                     15284
# Last Timing Belt Service Date    15903
# Available from                   15647
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 262023

# %%
df.count()
# Out:
# url                              15919
# make_model                       15919
# short_description                15873
# body_type                        15859
# price                            15919
# vat                              11406
# km                               15919
# registration                     15919
# prev_owner                        9091
# kW                                   0
# hp                               15919
# Type                             15917
# Previous Owners                   9279
# Next Inspection                   3535
# Inspection new                    3932
# Warranty                         10499
# Full Service                      8215
# Non-smoking Vehicle               7177
# null                             15919
# Make                             15919
# Model                            15919
# Offer Number                     12744
# First Registration               14322
# Body Color                       15322
# Paint Type                       10147
# Body Color Original              12160
# Upholstery                       12199
# Body                             15859
# Nr. of Doors                     15707
# Nr. of Seats                     14942
# Model Code                        4978
# Gearing Type                     15919
# Displacement                     15423
# Cylinders                        10239
# Weight                            8945
# Drive chain                       9061
# Fuel                             15919
# Consumption                      14013
# CO2 Emission                     14111
# Emission Class                   12898
# \nComfort & Convenience\n        14999
# Entertainment & Media            14545
# \nExtras\n                       12957
# \nSafety & Security\n            14937
# description                      15919
# Emission Label                    3985
# Gears                            11207
# Country version                   7586
# Electricity consumption            137
# Last Service Date                  566
# Other Fuel Types                   880
# Availability                       635
# Last Timing Belt Service Date       16
# Available from                     272
# dtype: int64

# %%
len(df["short_description"].unique())
# Out:
# 10002

# %%
df["short_description"].unique()
# Out:
# array(['Sportback 1.4 TDI S-tronic Xenon Navi Klima', '1.8 TFSI sport',
#        'Sportback 1.6 TDI S tronic Einparkhilfe plus+music', ...,
#        'ELYSEE ENERGY dCi 160 EDC',
#        'INITIALE Paris TCe 225 EDC GPF ACC EU6',
#        'TCe 225 EDC GPF LIM Deluxe Pano,RFK'], dtype=object)

# %%
df["make_model"].unique()
# Out:
# array(['Audi A1', 'Audi A2', 'Audi A3', 'Opel Astra', 'Opel Corsa',
#        'Opel Insignia', 'Renault Clio', 'Renault Duster',
#        'Renault Espace'], dtype=object)

# %%
df["make_model"]
# Out:
# 0               Audi A1
# 1               Audi A1
# 2               Audi A1
# 3               Audi A1
# 4               Audi A1
#               ...
# 15914    Renault Espace
# 15915    Renault Espace
# 15916    Renault Espace
# 15917    Renault Espace
# 15918    Renault Espace
# Name: make_model, Length: 15919, dtype: object

# %%
df.isnull()
# Out:
#          url  make_model  short_description  body_type  price    vat     km  registration  prev_owner    kW     hp   Type  Previous Owners  Next Inspection  Inspection new  Warranty  Full Service  Non-smoking Vehicle   null   Make  Model  Offer Number  First Registration  Body Color  Paint Type  Body Color Original  Upholstery   Body  Nr. of Doors  Nr. of Seats  Model Code  Gearing Type  Displacement  Cylinders  Weight  Drive chain   Fuel  Consumption  CO2 Emission  Emission Class  \nComfort & Convenience\n  Entertainment & Media  \nExtras\n  \nSafety & Security\n  description  Emission Label  Gears  Country version  Electricity consumption  Last Service Date  Other Fuel Types  Availability  Last Timing Belt Service Date  Available from
# 0      False       False              False      False  False  False  False         False       False  True  False  False            False            False           False     False         False                False  False  False  False         False               False       False       False                False       False  False         False         False       False         False         False      False   False        False  False        False         False           False                      False                  False       False                  False        False            True   True             True                     True               True              True          True                           True            True
# 1      False       False              False      False  False  False  False         False        True  True  False  False             True             True            True      True          True                 True  False  False  False          True               False       False        True                 True       False  False         False         False       False         False         False      False   False        False  False        False         False           False                      False                  False       False                  False        False           False  False             True                     True               True              True          True                           True            True
# 2      False       False              False      False  False  False  False         False       False  True  False  False            False             True            True     False          True                 True  False  False  False         False               False       False       False                False       False  False         False         False        True         False         False       True    True        False  False        False         False           False                      False                  False       False                  False        False           False   True             True                     True               True              True          True                           True            True
# 3      False       False              False      False  False   True  False         False       False  True  False  False            False             True            True      True         False                False  False  False  False          True               False       False       False                 True        True  False         False         False        True         False         False      False   False         True  False        False         False           False                      False                  False       False                  False        False            True  False             True                     True               True              True          True                           True            True
# 4      False       False              False      False  False   True  False         False       False  True  False  False            False             True           False     False         False                False  False  False  False         False               False       False       False                False       False  False         False         False       False         False         False      False    True        False  False        False         False           False                      False                  False       False                  False        False            True   True            False                     True               True              True          True                           True            True
# ...      ...         ...                ...        ...    ...    ...    ...           ...         ...   ...    ...    ...              ...              ...             ...       ...           ...                  ...    ...    ...    ...           ...                 ...         ...         ...                  ...         ...    ...           ...           ...         ...           ...           ...        ...     ...          ...    ...          ...           ...             ...                        ...                    ...         ...                    ...          ...             ...    ...              ...                      ...                ...               ...           ...                            ...             ...
# 15914  False       False              False      False  False  False  False         False        True  True  False  False             True             True            True     False          True                 True  False  False  False         False                True       False       False                False        True  False         False         False        True         False         False      False   False        False  False        False         False            True                      False                  False       False                  False        False            True  False             True                     True               True              True          True                           True            True
# 15915  False       False              False      False  False  False  False         False       False  True  False  False            False            False            True     False          True                False  False  False  False         False               False       False       False                False       False  False         False         False       False         False         False      False   False        False  False        False         False            True                      False                  False       False                  False        False            True  False            False                     True               True             False         False                           True            True
# 15916  False       False              False      False  False  False  False         False       False  True  False  False            False             True           False     False         False                False  False  False  False         False               False       False        True                False       False  False         False         False        True         False         False      False    True        False  False        False         False           False                      False                  False       False                  False        False            True  False            False                     True               True              True         False                           True            True
# 15917  False       False              False      False  False  False  False         False        True  True  False  False             True             True            True     False          True                 True  False  False  False         False               False       False        True                False       False  False         False         False        True         False         False      False   False        False  False        False         False           False                      False                  False       False                  False        False            True  False             True                     True               True              True          True                           True            True
# 15918  False       False              False      False  False  False  False         False       False  True  False  False            False             True           False      True          True                 True  False  False  False         False               False       False       False                False       False  False         False         False       False         False         False      False   False        False  False        False         False           False                      False                  False       False                  False        False           False   True            False                     True               True              True          True                           True            True
#
# [15919 rows x 54 columns]

# %%
len(df.isnull().sum().sort_values()) # 53 colomns var
# Out:
# 54

# %%
df.isnull().sum().sort_values(ascending=False) # df ‘deki eksik değerlerin sayısını öğrenelim ve azalan şekilde sıralayalım.
# Out:
# kW                               15919
# Last Timing Belt Service Date    15903
# Electricity consumption          15782
# Available from                   15647
# Last Service Date                15353
# Availability                     15284
# Other Fuel Types                 15039
# Next Inspection                  12384
# Inspection new                   11987
# Emission Label                   11934
# Model Code                       10941
# Non-smoking Vehicle               8742
# Country version                   8333
# Full Service                      7704
# Weight                            6974
# Drive chain                       6858
# prev_owner                        6828
# Previous Owners                   6640
# Paint Type                        5772
# Cylinders                         5680
# Warranty                          5420
# Gears                             4712
# vat                               4513
# Body Color Original               3759
# Upholstery                        3720
# Offer Number                      3175
# Emission Class                    3021
# \nExtras\n                        2962
# Consumption                       1906
# CO2 Emission                      1808
# First Registration                1597
# Entertainment & Media             1374
# \nSafety & Security\n              982
# Nr. of Seats                       977
# \nComfort & Convenience\n          920
# Body Color                         597
# Displacement                       496
# Nr. of Doors                       212
# Body                                60
# body_type                           60
# short_description                   46
# Type                                 2
# Fuel                                 0
# null                                 0
# Make                                 0
# hp                                   0
# Model                                0
# Gearing Type                         0
# registration                         0
# km                                   0
# description                          0
# price                                0
# make_model                           0
# url                                  0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100 # stun bazinda stunun bos olanlarinin % lik oranini veriyor
# Out:
# url                                0.000000
# make_model                         0.000000
# short_description                  0.288963
# body_type                          0.376908
# price                              0.000000
# vat                               28.349771
# km                                 0.000000
# registration                       0.000000
# prev_owner                        42.892141
# kW                               100.000000
# hp                                 0.000000
# Type                               0.012564
# Previous Owners                   41.711163
# Next Inspection                   77.793831
# Inspection new                    75.299956
# Warranty                          34.047365
# Full Service                      48.395000
# Non-smoking Vehicle               54.915510
# null                               0.000000
# Make                               0.000000
# Model                              0.000000
# Offer Number                      19.944720
# First Registration                10.032037
# Body Color                         3.750236
# Paint Type                        36.258559
# Body Color Original               23.613292
# Upholstery                        23.368302
# Body                               0.376908
# Nr. of Doors                       1.331742
# Nr. of Seats                       6.137320
# Model Code                        68.729192
# Gearing Type                       0.000000
# Displacement                       3.115774
# Cylinders                         35.680633
# Weight                            43.809285
# Drive chain                       43.080596
# Fuel                               0.000000
# Consumption                       11.973114
# CO2 Emission                      11.357497
# Emission Class                    18.977323
# \nComfort & Convenience\n          5.779257
# Entertainment & Media              8.631195
# \nExtras\n                        18.606696
# \nSafety & Security\n              6.168729
# description                        0.000000
# Emission Label                    74.967021
# Gears                             29.599849
# Country version                   52.346253
# Electricity consumption           99.139393
# Last Service Date                 96.444500
# Other Fuel Types                  94.472015
# Availability                      96.011056
# Last Timing Belt Service Date     99.899491
# Available from                    98.291350
# dtype: float64

# %%
a = df.isnull().sum()/len(df)*100
#ri.isnull().sum().sort_values(ascending=False)
a.sort_values()
# Out:
# url                                0.000000
# make_model                         0.000000
# price                              0.000000
# description                        0.000000
# km                                 0.000000
# registration                       0.000000
# Gearing Type                       0.000000
# Model                              0.000000
# hp                                 0.000000
# Make                               0.000000
# null                               0.000000
# Fuel                               0.000000
# Type                               0.012564
# short_description                  0.288963
# body_type                          0.376908
# Body                               0.376908
# Nr. of Doors                       1.331742
# Displacement                       3.115774
# Body Color                         3.750236
# \nComfort & Convenience\n          5.779257
# Nr. of Seats                       6.137320
# \nSafety & Security\n              6.168729
# Entertainment & Media              8.631195
# First Registration                10.032037
# CO2 Emission                      11.357497
# Consumption                       11.973114
# \nExtras\n                        18.606696
# Emission Class                    18.977323
# Offer Number                      19.944720
# Upholstery                        23.368302
# Body Color Original               23.613292
# vat                               28.349771
# Gears                             29.599849
# Warranty                          34.047365
# Cylinders                         35.680633
# Paint Type                        36.258559
# Previous Owners                   41.711163
# prev_owner                        42.892141
# Drive chain                       43.080596
# Weight                            43.809285
# Full Service                      48.395000
# Country version                   52.346253
# Non-smoking Vehicle               54.915510
# Model Code                        68.729192
# Emission Label                    74.967021
# Inspection new                    75.299956
# Next Inspection                   77.793831
# Other Fuel Types                  94.472015
# Availability                      96.011056
# Last Service Date                 96.444500
# Available from                    98.291350
# Electricity consumption           99.139393
# Last Timing Belt Service Date     99.899491
# kW                               100.000000
# dtype: float64

# %%
(df.isnull().sum()/len(df)*100).sort_values() # bos olanlarinin % lik orani
# Out:
# url                                0.000000
# make_model                         0.000000
# price                              0.000000
# description                        0.000000
# km                                 0.000000
# registration                       0.000000
# Gearing Type                       0.000000
# Model                              0.000000
# hp                                 0.000000
# Make                               0.000000
# null                               0.000000
# Fuel                               0.000000
# Type                               0.012564
# short_description                  0.288963
# body_type                          0.376908
# Body                               0.376908
# Nr. of Doors                       1.331742
# Displacement                       3.115774
# Body Color                         3.750236
# \nComfort & Convenience\n          5.779257
# Nr. of Seats                       6.137320
# \nSafety & Security\n              6.168729
# Entertainment & Media              8.631195
# First Registration                10.032037
# CO2 Emission                      11.357497
# Consumption                       11.973114
# \nExtras\n                        18.606696
# Emission Class                    18.977323
# Offer Number                      19.944720
# Upholstery                        23.368302
# Body Color Original               23.613292
# vat                               28.349771
# Gears                             29.599849
# Warranty                          34.047365
# Cylinders                         35.680633
# Paint Type                        36.258559
# Previous Owners                   41.711163
# prev_owner                        42.892141
# Drive chain                       43.080596
# Weight                            43.809285
# Full Service                      48.395000
# Country version                   52.346253
# Non-smoking Vehicle               54.915510
# Model Code                        68.729192
# Emission Label                    74.967021
# Inspection new                    75.299956
# Next Inspection                   77.793831
# Other Fuel Types                  94.472015
# Availability                      96.011056
# Last Service Date                 96.444500
# Available from                    98.291350
# Electricity consumption           99.139393
# Last Timing Belt Service Date     99.899491
# kW                               100.000000
# dtype: float64

# %%
# (df.isnull().sum()/df.shape[0]*100).sort_values(ascending =False)

# %% [markdown]
# """ """Aşağıdaki ayrıntılı bir özet veriyor.
# pip install pandas-profiling
# import pandas_profiling
# pandas_profiling.ProfileReport(oto)""""""

# %%
col_list = list(df.columns)
col_list
# Out:
# ['make_model',
#  'short_description',
#  'body_type',
#  'price',
#  'vat',
#  'km',
#  'registration',
#  'prev_owner',
#  'hp',
#  'Type',
#  'Previous Owners',
#  'Next Inspection',
#  'Inspection new',
#  'Warranty',
#  'Full Service',
#  'Non-smoking Vehicle',
#  'Make',
#  'Offer Number',
#  'First Registration',
#  'Body Color',
#  'Paint Type',
#  'Body Color Original',
#  'Upholstery',
#  'Body',
#  'Nr. of Doors',
#  'Nr. of Seats',
#  'Model Code',
#  'Gearing Type',
#  'Displacement',
#  'Cylinders',
#  'Weight',
#  'Drive chain',
#  'Fuel',
#  'Consumption',
#  'CO2 Emission',
#  'Emission Class',
#  '\nComfort & Convenience\n',
#  'Entertainment & Media',
#  '\nExtras\n',
#  '\nSafety & Security\n',
#  'description',
#  'Emission Label',
#  'Gears',
#  'Country version',
#  'Last Service Date',
#  'Availability',
#  'Available from']

# %%
def fill_most(oto, group_col, ):

# %%
df["make_model"].unique()
# Out:
# array(['Audi A1', 'Audi A2', 'Audi A3', 'Opel Astra', 'Opel Corsa',
#        'Opel Insignia', 'Renault Clio', 'Renault Duster',
#        'Renault Espace'], dtype=object)

# %%
for group in list(df["group_col"].unique()):

# %%
grp_inx=list(df[df["group_col"] == "group"]["col_name"].index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'group_col'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-31f800df26fc> in <module>
# ----> 1 grp_inx=list(df[df["group_col"] == "group"]["col_name"].index)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'group_col'

# %% [markdown]
# ### Drop unnecessary Columns / Dropping irrelevant columns

# %%
## Drop out the columns with high NAN values, which will not affect the car price. 
    # "kW" , "Last Timing Belt Service Date" , "Electricity consumption" : %99

## Remove columns with only one type of data that won't affect the vehicle price. 
    # "Other Fuel Types" , "url", "null" , 
## Drop one of the columns containing the same data
    # "Model" ,

# %%
# df.dropna(axis=1, how = 'all') # axis=1 oldugundan Y ekseni boyunca yani stunlardan herhangi birinde hepsi NaN olsaydi o stunu giderdi

# %%
df = df.drop(["kW" , "Last Timing Belt Service Date" , "Electricity consumption", "Other Fuel Types" , "url", "null", "Model"], axis=1)

# %%
# df.dropna(axis=1, how = 'all') # axis=1 oldugundan Y ekseni boyunca yani stunlardan herhangi birinde hepsi NaN olsaydi o stunu giderdi

# %%
df.head(1)
# Out:
#   make_model                            short_description body_type  price             vat         km registration         prev_owner     hp                                     Type Previous Owners                        Next Inspection         Inspection new                 Warranty Full Service Non-smoking Vehicle      Make     Offer Number First Registration       Body Color      Paint Type  Body Color Original          Upholstery              Body Nr. of Doors Nr. of Seats      Model Code         Gearing Type    Displacement Cylinders          Weight  Drive chain                                   Fuel                                                               Consumption              CO2 Emission Emission Class                                                                                                                                                                                                                                                                                                     \nComfort & Convenience\n                                        Entertainment & Media                                          \nExtras\n                                                                                                                                                                                                                                         \nSafety & Security\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          description Emission Label Gears Country version Last Service Date Availability Available from
# 0    Audi A1  Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770  VAT deductible  56,013 km      01/2016  2 previous owners  66 kW  [, Used, , Diesel (Particulate Filter)]           \n2\n  [\n06/2021\n, \n99 g CO2/km (comb)\n]  [\nYes\n, \nEuro 6\n]  [\n, \n, \n4 (Green)\n]     [\n, \n]            [\n, \n]  \nAudi\n  [\nLR-062483\n]     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]  [\nMythosschwarz\n]  [\nCloth, Black\n]  [\n, Sedans, \n]      [\n5\n]      [\n5\n]  [\n0588/BDF\n]  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]  [\n1,220 kg\n]  [\nfront\n]  [\n, Diesel (Particulate Filter), \n]  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)], [3.5 l/100 km (country)]]  [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]  [Air conditioning, Armrest, Automatic climate control, Cruise control, Electrical side mirrors, Hill Holder, Leather steering wheel, Light sensor, Multi-function steering wheel, Navigation system, Park Distance Control, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Start-stop system]  [Bluetooth, Hands-free equipment, On-board computer, Radio]  [Alloy wheels, Catalytic Converter, Voice Control]  [ABS, Central door lock, Daytime running lights, Driver-side airbag, Electronic stability control, Fog lights, Immobilizer, Isofix, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control, Xenon headlights]  [\n, Sicherheit:,  , Deaktivierung für Beifahrer-Airbag,  , ESC mit elektronischer Quersperre,  , Tagfahrlicht,  , Reifendruck-Kontrollanzeige,  , Kopfairbag-System mit Seiten-Airbags vorn,  , Sicherheitslenksäule, Assistenzsysteme:,  , Berganfahrassistent, Komfort:,  , Scheinwerferreinigung,  , Xenon plus inklusive Scheinwerfer-Reinigungsanlage,  , Scheinwerfer-Reinigungsanlage,  , Einparkhilfe hinten,  , Licht-/Regensensor,  , Funkfernbedienung,  , Elektrische Luftzusatzheizung, Interieur:...            NaN   NaN             NaN               NaN          NaN            NaN

# %%
df['Electricity*'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Electricity*'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-106-f7c277e3db75> in <module>
# ----> 1 df['Electricity*'].value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Electricity*'

# %%
def show_nans(df, limit):
    missing = df.isnull().sum()*100/df.shape[0]
    return missing.loc[lambda x : x > limit]

# %%
show_nans(df,95)
# Out:
# Last Service Date    96.444500
# Availability         96.011056
# Available from       98.291350
# dtype: float64

# %%
show_nans(df,35)
# Out:
# prev_owner             42.892141
# Previous Owners        41.711163
# Next Inspection        77.793831
# Inspection new         75.299956
# Full Service           48.395000
# Non-smoking Vehicle    54.915510
# Paint Type             36.258559
# Model Code             68.729192
# Cylinders              35.680633
# Weight                 43.809285
# Drive chain            43.080596
# Emission Label         74.967021
# Country version        52.346253
# Last Service Date      96.444500
# Availability           96.011056
# Available from         98.291350
# dtype: float64

# %% [markdown]
# prew_owner and previous owner

# %%
df.groupby('make_model')["price"].mean()
# Out:
# make_model
# Audi A1           18864.688982
# Audi A2           28200.000000
# Audi A3           20996.693252
# Opel Astra        15834.663895
# Opel Corsa        11047.095539
# Opel Insignia     21463.451886
# Renault Clio      11940.320827
# Renault Duster    13230.176471
# Renault Espace    30080.211907
# Name: price, dtype: float64

# %%
missing = df.isnull().sum()*100/df.shape[0]
    return missing.loc[lambda x : x > limit]
show_nans(df,65)
# Out:
#   File "<ipython-input-119-7b15d3aa3389>", line 2
#     return missing.loc[lambda x : x > limit]
#     ^
# IndentationError: unexpected indent

# %%
## df.groupby('make_model')["price"].transform('mean') # NaN olan degerlere ortalama INTEGER ile doldurmak icin

# %%
df1 = pd.DataFrame({'lkey': ['x', 'y', 'z', 'c', 'z','x'],
                    'lvalue': [2, 3, 5, 7, 0, 99]})
df2 = pd.DataFrame({'rkey': ['x', 'x', 'z', 'z'],
                    'rvalue': [7, 8, 9, 10]})

# %%
df1
# Out:
#   lkey  lvalue
# 0    x       2
# 1    y       3
# 2    z       5
# 3    c       7
# 4    z       0
# 5    x      99

# %%
df2
# Out:
#   rkey  rvalue
# 0    x       7
# 1    x       8
# 2    z       9
# 3    z      10

# %%
pd.merge(df1, df2, left_on ="lkey",  right_on ="rkey", how="left" )
# Out:
#   lkey  lvalue rkey  rvalue
# 0    x       2    x     7.0
# 1    x       2    x     8.0
# 2    y       3  NaN     NaN
# 3    z       5    z     9.0
# 4    z       5    z    10.0
# 5    c       7  NaN     NaN
# 6    z       0    z     9.0
# 7    z       0    z    10.0
# 8    x      99    x     7.0
# 9    x      99    x     8.0
