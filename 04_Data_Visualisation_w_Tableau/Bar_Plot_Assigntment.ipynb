# %%
import numpy as np
import pandas as pd
from collections import Counter
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('bar_data.csv')

# %%
df.head()
# Out:
#    Responder_id                          LanguagesWorkedWith
# 0             1              HTML/CSS;Java;JavaScript;Python
# 1             2                          C++;HTML/CSS;Python
# 2             3                                     HTML/CSS
# 3             4                          C;C++;C#;Python;SQL
# 4             5  C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA

# %%
df.shape
# Out:
# (87569, 2)

# %%
df.LanguagesWorkedWith.nunique()
# Out:
# 20098

# %%
df["langs"] = df["LanguagesWorkedWith"].apply(lambda x: x.split(";"))

# %%
df.head()
# Out:
#    Responder_id                          LanguagesWorkedWith  \
# 0             1              HTML/CSS;Java;JavaScript;Python
# 1             2                          C++;HTML/CSS;Python
# 2             3                                     HTML/CSS
# 3             4                          C;C++;C#;Python;SQL
# 4             5  C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#
#                                                langs
# 0               [HTML/CSS, Java, JavaScript, Python]
# 1                            [C++, HTML/CSS, Python]
# 2                                         [HTML/CSS]
# 3                          [C, C++, C#, Python, SQL]
# 4  [C++, HTML/CSS, Java, JavaScript, Python, SQL,...

# %%
df.langs[0]
# Out:
# ['HTML/CSS', 'Java', 'JavaScript', 'Python']

# %%
df.langs[0][1]
# Out:
# 'Java'

# %%
total_list=[]

# %%
for k in df.langs[0]:
    print(k)
# Out:
# HTML/CSS
# Java
# JavaScript
# Python

# %%
for i in range(len(df.langs)):
    for k in df.langs[i]:
        total_list.append(k)

# %%
total_list
# Out:
# ['HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Python',
#  'C++',
#  'HTML/CSS',
#  'Python',
#  'HTML/CSS',
#  'C',
#  'C++',
#  'C#',
#  'Python',
#  'SQL',
#  'C++',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Python',
#  'SQL',
#  'VBA',
#  'Java',
#  'R',
#  'SQL',
#  'HTML/CSS',
#  'JavaScript',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Python',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'Python',
#  'Ruby',
#  'Rust',
#  'SQL',
#  'TypeScript',
#  'WebAssembly',
#  'Other(s):',
#  'C#',
#  'Go',
#  'JavaScript',
#  'Python',
#  'R',
#  'SQL',
#  'Other(s):',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'Java',
#  'Python',
#  'R',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'JavaScript',
#  'PHP',
#  'SQL',
#  'TypeScript',
#  'C++',
#  'Assembly',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'TypeScript',
#  'VBA',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'JavaScript',
#  'TypeScript',
#  'Python',
#  'R',
#  'C#',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'SQL',
#  'TypeScript',
#  'Bash/Shell/PowerShell',
#  'C#',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'R',
#  'SQL',
#  'Assembly',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'Go',
#  'Java',
#  'JavaScript',
#  'Kotlin',
#  'Python',
#  'Rust',
#  'SQL',
#  'Swift',
#  'Bash/Shell/PowerShell',
#  'C++',
#  'HTML/CSS',
#  'JavaScript',
#  'Python',
#  'Ruby',
#  'SQL',
#  'TypeScript',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'JavaScript',
#  'Python',
#  'Ruby',
#  'SQL',
#  'HTML/CSS',
#  'JavaScript',
#  'PHP',
#  'TypeScript',
#  'HTML/CSS',
#  'JavaScript',
#  'PHP',
#  'SQL',
#  'TypeScript',
#  'Bash/Shell/PowerShell',
#  'C++',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'Ruby',
#  'SQL',
#  'Swift',
#  'TypeScript',
#  'VBA',
#  'C++',
#  'JavaScript',
#  'Python',
#  'Ruby',
#  'SQL',
#  'TypeScript',
#  'JavaScript',
#  'TypeScript',
#  'Bash/Shell/PowerShell',
#  'JavaScript',
#  'SQL',
#  'Python',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'C++',
#  'Python',
#  'R',
#  'HTML/CSS',
#  'JavaScript',
#  'HTML/CSS',
#  'JavaScript',
#  'Java',
#  'Kotlin',
#  'Python',
#  'Bash/Shell/PowerShell',
#  'JavaScript',
#  'Python',
#  'Other(s):',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'SQL',
#  'C#',
#  'JavaScript',
#  'SQL',
#  'TypeScript',
#  'C#',
#  'HTML/CSS',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'SQL',
#  'HTML/CSS',
#  'JavaScript',
#  'PHP',
#  'TypeScript',
#  'C++',
#  'C#',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Objective-C',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'C#',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'SQL',
#  'TypeScript',
#  'WebAssembly',
#  'Python',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'SQL',
#  'Other(s):',
#  'Java',
#  'PHP',
#  'Ruby',
#  'HTML/CSS',
#  'PHP',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'SQL',
#  'TypeScript',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'C++',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Python',
#  'R',
#  'TypeScript',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'Elixir',
#  'Erlang',
#  'Go',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Kotlin',
#  'Python',
#  'Ruby',
#  'Rust',
#  'SQL',
#  'TypeScript',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'SQL',
#  'TypeScript',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'JavaScript',
#  'Python',
#  'Java',
#  'Python',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'Java',
#  'SQL',
#  'JavaScript',
#  'Python',
#  'C#',
#  'Java',
#  'SQL',
#  'HTML/CSS',
#  'JavaScript',
#  'PHP',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'Go',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'Ruby',
#  'SQL',
#  'C++',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'SQL',
#  'VBA',
#  'Bash/Shell/PowerShell',
#  'C++',
#  'Go',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Kotlin',
#  'PHP',
#  'Python',
#  'Ruby',
#  'SQL',
#  'TypeScript',
#  'VBA',
#  'Bash/Shell/PowerShell',
#  'Clojure',
#  'Java',
#  'Python',
#  'Other(s):',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'C#',
#  'Assembly',
#  'C',
#  'C++',
#  'C#',
#  'HTML/CSS',
#  'Java',
#  'Clojure',
#  'Go',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'R',
#  'SQL',
#  'C',
#  'C#',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'SQL',
#  'VBA',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Python',
#  'C#',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Objective-C',
#  'SQL',
#  'TypeScript',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'SQL',
#  'HTML/CSS',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'SQL',
#  'VBA',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'PHP',
#  'SQL',
#  'TypeScript',
#  'SQL',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Kotlin',
#  'Python',
#  'Ruby',
#  'HTML/CSS',
#  'JavaScript',
#  'PHP',
#  'SQL',
#  'HTML/CSS',
#  'JavaScript',
#  'PHP',
#  'SQL',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Kotlin',
#  'Python',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'TypeScript',
#  'Bash/Shell/PowerShell',
#  'C#',
#  'F#',
#  'Go',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Python',
#  'SQL',
#  'TypeScript',
#  'Assembly',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'Python',
#  'Bash/Shell/PowerShell',
#  'C++',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Python',
#  'Rust',
#  'HTML/CSS',
#  'JavaScript',
#  'C',
#  'C++',
#  'C#',
#  'Java',
#  'Kotlin',
#  'PHP',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'SQL',
#  'TypeScript',
#  'Bash/Shell/PowerShell',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'C#',
#  'Go',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Objective-C',
#  'Python',
#  'SQL',
#  'C++',
#  'C#',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'SQL',
#  'TypeScript',
#  'Bash/Shell/PowerShell',
#  'Python',
#  'Bash/Shell/PowerShell',
#  'C#',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Objective-C',
#  'PHP',
#  'Python',
#  'Ruby',
#  'SQL',
#  'Swift',
#  'TypeScript',
#  'HTML/CSS',
#  'JavaScript',
#  'TypeScript',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Kotlin',
#  'SQL',
#  'VBA',
#  'Python',
#  'SQL',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'SQL',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'Python',
#  'R',
#  'SQL',
#  'C',
#  'C++',
#  'Java',
#  'Python',
#  'R',
#  'Scala',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'JavaScript',
#  'Python',
#  'R',
#  'SQL',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'SQL',
#  'C',
#  'C++',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Kotlin',
#  'PHP',
#  'Python',
#  'SQL',
#  'HTML/CSS',
#  'JavaScript',
#  'Ruby',
#  'SQL',
#  'TypeScript',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'JavaScript',
#  'SQL',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'SQL',
#  'TypeScript',
#  'Clojure',
#  'Go',
#  'Java',
#  'Kotlin',
#  'C#',
#  'HTML/CSS',
#  'TypeScript',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'JavaScript',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Python',
#  'SQL',
#  'HTML/CSS',
#  'Java',
#  'Python',
#  'C++',
#  'Python',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'SQL',
#  'Python',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'Python',
#  'SQL',
#  'VBA',
#  'Assembly',
#  'C',
#  'C++',
#  'C#',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Python',
#  'VBA',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'Bash/Shell/PowerShell',
#  'C++',
#  'Erlang',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'Assembly',
#  'C#',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'SQL',
#  'Swift',
#  'Scala',
#  'Other(s):',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'SQL',
#  'TypeScript',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'C',
#  'C++',
#  'C#',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'SQL',
#  'Elixir',
#  'HTML/CSS',
#  'JavaScript',
#  'Python',
#  'Ruby',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'HTML/CSS',
#  'JavaScript',
#  'Python',
#  'Assembly',
#  'Bash/Shell/PowerShell',
#  'C++',
#  'Python',
#  'SQL',
#  'HTML/CSS',
#  'JavaScript',
#  'TypeScript',
#  'HTML/CSS',
#  'Java',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'Dart',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Scala',
#  'C#',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'C',
#  'Python',
#  'Bash/Shell/PowerShell',
#  'Go',
#  'Ruby',
#  'C++',
#  'Python',
#  'R',
#  'Bash/Shell/PowerShell',
#  'C++',
#  'Clojure',
#  'HTML/CSS',
#  'Java',
#  'Python',
#  'Ruby',
#  'SQL',
#  'Java',
#  'Bash/Shell/PowerShell',
#  'C++',
#  'C#',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Objective-C',
#  'Python',
#  'TypeScript',
#  'JavaScript',
#  'PHP',
#  'SQL',
#  'C',
#  'C++',
#  'HTML/CSS',
#  'JavaScript',
#  'SQL',
#  'Go',
#  'HTML/CSS',
#  'JavaScript',
#  'TypeScript',
#  'C#',
#  'Java',
#  'PHP',
#  'Python',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'SQL',
#  'Java',
#  'JavaScript',
#  'Kotlin',
#  'PHP',
#  'SQL',
#  'Assembly',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Python',
#  'SQL',
#  'TypeScript',
#  'Bash/Shell/PowerShell',
#  'C#',
#  'C',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Python',
#  'SQL',
#  'TypeScript',
#  'Java',
#  'SQL',
#  'Assembly',
#  'C++',
#  'Python',
#  'VBA',
#  'Bash/Shell/PowerShell',
#  'C',
#  'Python',
#  'Scala',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Kotlin',
#  'HTML/CSS',
#  'JavaScript',
#  'TypeScript',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'JavaScript',
#  'Python',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'C#',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Python',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'C++',
#  'C#',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'SQL',
#  'TypeScript',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Kotlin',
#  'Objective-C',
#  'Python',
#  'Swift',
#  'Other(s):',
#  'C',
#  'C++',
#  'Python',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'SQL',
#  'VBA',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'JavaScript',
#  'TypeScript',
#  'Bash/Shell/PowerShell',
#  'Python',
#  'Bash/Shell/PowerShell',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'SQL',
#  'Java',
#  'SQL',
#  'Other(s):',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'JavaScript',
#  'Python',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'PHP',
#  'Bash/Shell/PowerShell',
#  'C++',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'SQL',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'SQL',
#  'Other(s):',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'SQL',
#  'Assembly',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'C#',
#  'JavaScript',
#  'Python',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'Go',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Ruby',
#  'SQL',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'Python',
#  'C',
#  'C++',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'SQL',
#  'Clojure',
#  'Go',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Python',
#  'Ruby',
#  'TypeScript',
#  'Assembly',
#  'C',
#  'C++',
#  'C#',
#  'HTML/CSS',
#  'Java',
#  'Objective-C',
#  'PHP',
#  'Python',
#  'R',
#  'SQL',
#  'Swift',
#  'HTML/CSS',
#  'JavaScript',
#  'Objective-C',
#  'SQL',
#  'HTML/CSS',
#  'JavaScript',
#  'PHP',
#  'SQL',
#  'TypeScript',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'R',
#  'Assembly',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'SQL',
#  'C',
#  'C++',
#  'C#',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Python',
#  'SQL',
#  'C#',
#  'Python',
#  'SQL',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'Ruby',
#  'SQL',
#  'TypeScript',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Objective-C',
#  'SQL',
#  'Swift',
#  'HTML/CSS',
#  'JavaScript',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'Go',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'Rust',
#  'SQL',
#  'TypeScript',
#  'Dart',
#  'Go',
#  'Java',
#  'Kotlin',
#  'Swift',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'Java',
#  'JavaScript',
#  'Kotlin',
#  'Objective-C',
#  'Python',
#  'Rust',
#  'Swift',
#  'Bash/Shell/PowerShell',
#  'Java',
#  'Kotlin',
#  'Assembly',
#  'C',
#  'C++',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Python',
#  'HTML/CSS',
#  'JavaScript',
#  'Ruby',
#  'Scala',
#  'SQL',
#  'C#',
#  'Python',
#  'R',
#  'SQL',
#  'VBA',
#  'C++',
#  'HTML/CSS',
#  'JavaScript',
#  'Python',
#  'SQL',
#  'Java',
#  'Scala',
#  'SQL',
#  'TypeScript',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'SQL',
#  'TypeScript',
#  'Bash/Shell/PowerShell',
#  'JavaScript',
#  'Python',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'JavaScript',
#  'Ruby',
#  'SQL',
#  'Assembly',
#  'Bash/Shell/PowerShell',
#  'C',
#  'HTML/CSS',
#  'Java',
#  ...]

# %%
most_common_langs=lang_count.most_common(15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-dfff69c7f6ee> in <module>
# ----> 1 most_common_langs=lang_count.most_common(15)
#
# NameError: name 'lang_count' is not defined

# %%
total_list=[:20]
# Out:
#   File "<ipython-input-38-771c33ec68b4>", line 1
#     total_list=[:20]
#                 ^
# SyntaxError: invalid syntax

# %%
c

# %%
pd.Series(df['LanguagesWorkedWith'].str.replace('[\[\]\']','').str.split(';').map(Counter).sum())

# %%
fig, ax = plt.subplots(figsize=(15, 7))
rects1=ax.bar(x, y)
ax.set_title("Most Popular Languages")
ax.set_ylabel('Number of People Who Use')
ax.set_xticks(x_pos)
ax.set_xticklabels(x, rotation=45);

# %%
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
autolabel(rects1)
