# %% [markdown]
# # Pandas Built-in Data Visualization
#
# In this lecture we will learn about pandas built-in capabilities for data visualization! It's built-off of matplotlib, but it baked into pandas for easier usage!
#
# Let's take a look!

# %% [markdown]
# -- Q: Is it possible to plot histogram in Pandas without calling Matplotlib? --
#
# A: Yes you can use Pandas Built-in capabilities that are actually built of Matplotlib, but allow you to call data visualization commands directly via Pandas without calling Matplotlib.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## The Data
#
# There are some fake data csv files you can read in as dataframes:

# %%
df1 = pd.read_csv('df1',index_col=0)
df2 = pd.read_csv('df2')

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
sns.set_style("darkgrid")

# %%
df1["A"].hist()

# %%
df = pd.DataFrame({'sales': [3, 2, 3, 9, 10, 6], 'signups': [5, 5, 6, 12, 14, 13],
                   'visits': [20, 42, 28, 62, 81, 50]},
                  index=pd.date_range(start='2018/01/01', end='2018/07/01',
                                      freq='M'))
df.head()
# Out:
#             sales  signups  visits
# 2018-01-31      3        5      20
# 2018-02-28      2        5      42
# 2018-03-31      3        6      28
# 2018-04-30      9       12      62
# 2018-05-31     10       14      81

# %%
df.plot.area(figsize=(9,6)) # Nerede kullanilir elemanlarin herbirini gormek kadar totalide gormek onemli ise

# %%
df.plot(kind="area", figsize=(9,6))

# %% [markdown]
# barplots

# %%
speed = [0.1, 17.5, 40, 48, 52, 69, 88]
lifespan = [2, 8, 70, 1.5, 25, 12, 28]
index = ['snail', 'pig', 'elephant','rabbit', 'giraffe', 'coyote', 'horse']
df = pd.DataFrame({'speed': speed,'lifespan': lifespan}, index=index)
df.head()
# Out:
#           speed  lifespan
# snail       0.1       2.0
# pig        17.5       8.0
# elephant   40.0      70.0
# rabbit     48.0       1.5
# giraffe    52.0      25.0

# %%
df.plot.bar(figsize=(7,4))

# %%
value_counts(sort=False).plot.bar(rot=0, color="b", figsize=(6,4)) .
# Out:
#   File "<ipython-input-12-0149066811b8>", line 1
#     value_counts(sort=False).plot.bar(rot=0, color="b", figsize=(6,4)) .
#                                                                         ^
# SyntaxError: invalid syntax

# %%
df.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-986e25863b45> in <module>
# ----> 1 df.value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
df.['speed'].value_counts()
# Out:
#   File "<ipython-input-14-dbdea5de2e3b>", line 1
#     df.['speed'].value_counts()
#        ^
# SyntaxError: invalid syntax

# %%
order = df['speed'].value_counts().index
plt.show()
order.plot.bar(figsize=(7,4), rot=45)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-d190adb25126> in <module>
#       1 order = df['speed'].value_counts().index
#       2 plt.show()
# ----> 3 order.plot.bar(figsize=(7,4), rot=45)
#
# AttributeError: 'Float64Index' object has no attribute 'plot'

# %%
df.plot.bar(figsize=(7,4), rot=45)
plt.axhline(y=50, color="green", ls="--")

# %%
g = df.plot.bar(figsize=(7,4), rot=45)
for p in g.patches:
    g.annotate((p.get_height()), (p.get_x()+0.02, p.get_height()+0.5))

# %%
Labels = ['Snail', 'Pig', 'Elephant','Rabbit', 'Giraffe', 'Coyote', 'Horse']

# %%
g = df.plot.bar(figsize=(7,4), rot=45)

g.set_xticklabels("labels")

g.set_ylabel('speed/lifespan')

for p in g.patches:
    g.annotate((p.get_height()), (p.get_x()+0.02, p.get_height()+0.5))

# %%
income = [100, 80, 150, 48, 52, 69, 88]
expense = [30, 100, 100, 20, 75, 50, 28]
index = ['snail', 'pig', 'elephant','rabbit', 'giraffe', 'coyote', 'horse']
df = pd.DataFrame({'income': income,'expense': expense}, index=index)
df.head()
# Out:
#           income  expense
# snail        100       30
# pig           80      100
# elephant     150      100
# rabbit        48       20
# giraffe       52       75

# %%
df.plot.bar(figsize=(8,4))

# %%
df.plot.bar(stacked=True)

# %%
df["profit"] = df.income - df.expense

# %%
df
# Out:
#           income  expense  profit
# snail        100       30      70
# pig           80      100     -20
# elephant     150      100      50
# rabbit        48       20      28
# giraffe       52       75     -23
# coyote        69       50      19
# horse         88       28      60

# %%
df.plot.bar()

# %% [markdown]
# # histograms

# %%
mpg=sns.load_dataset("mpg")

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.horsepower.plot.hist(bins=20)

# %%
mpg.horsepower.plot(kind="hist", bins=20)

# %% [markdown]
# ## LINEPLOTS

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1["B"].plot()

# %%
df1["B"].plot.line()

# %%
df1.plot.line(y="B", figsize=(10,6))

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df1.plot.line(y="B", figsize=(10,6))

# %%
df1.B.head()
# Out:
# 2000-01-01   -0.163643
# 2000-01-02    0.137034
# 2000-01-03   -0.482943
# 2000-01-04   -0.072973
# 2000-01-05    1.778576
# Name: B, dtype: float64

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.groupby("model_year").horsepower.mean().plot()

# %%
mpg.groupby("model_year").mpg.mean().plot(ls = "--")

# %%
from pandas_datareader import data
from datetime import datetime
start = datetime(2020, 1, 1)
end = datetime(2020, 8, 30)

# %%
f = data.DataReader(name="AAPL", data_source="av-daily", start=start, end=end, api_key = "CI1UUA44YI12JAB3")

# %%
# https://www.alpavantage.co/support/#api-key   *** to create the api key

# %%
f.head()
# Out:
#               open    high     low   close    volume
# 2020-01-02  296.24  300.60  295.19  300.35  33870100
# 2020-01-03  297.15  300.58  296.50  297.43  36580700
# 2020-01-06  293.79  299.96  292.75  299.80  29596800
# 2020-01-07  299.84  300.90  297.48  298.39  27218000
# 2020-01-08  297.16  304.44  297.16  303.19  33019800

# %%
f.tail()
# Out:
#                 open      high      low   close    volume
# 2020-08-24  514.7900  515.1400  495.745  503.43  86484442
# 2020-08-25  498.7900  500.7172  492.210  499.30  52873947
# 2020-08-26  504.7165  507.9700  500.330  506.09  40755567
# 2020-08-27  508.5700  509.9400  495.330  500.04  38888096
# 2020-08-28  504.0500  505.7700  498.310  499.23  46907479

# %%
f.index=pd.to_datetime(f.index)

# %%
f.close.plot(figsize=(10,7))

# %%
import matplotlib.dates as mdates
import numpy as np
fig, ax = plt.subplots(figsize=(10,7))
#ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
ax.set_xticklabels(f.index, rotation=45)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=15))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.plot(f.close.index, f.close);

# %% [markdown]
# ## moving avgs

# %%
seven = f.close.rolling(window = 7).mean()

# %%
seven.head(10)
# Out:
# 2020-01-02           NaN
# 2020-01-03           NaN
# 2020-01-06           NaN
# 2020-01-07           NaN
# 2020-01-08           NaN
# 2020-01-09           NaN
# 2020-01-10    302.731429
# 2020-01-13    305.104286
# 2020-01-14    307.282857
# 2020-01-15    308.931429
# Name: close, dtype: float64

# %%
ten = f.close.rolling(window = 10).mean() # yedi gunluk hareketli ortalamayi veriyor

# %%
ten.head(15)
# Out:
# 2020-01-02        NaN
# 2020-01-03        NaN
# 2020-01-06        NaN
# 2020-01-07        NaN
# 2020-01-08        NaN
# 2020-01-09        NaN
# 2020-01-10        NaN
# 2020-01-13        NaN
# 2020-01-14        NaN
# 2020-01-15    306.010
# 2020-01-16    307.499
# 2020-01-17    309.629
# 2020-01-21    311.306
# 2020-01-22    313.237
# 2020-01-23    314.841
# Name: close, dtype: float64

# %%
twenty = f.close.rolling(window = 20).mean()

# %%
thirty = f.close.rolling(window = 30).mean()

# %%
plt.figure(figsize=(15,10))
f.close.plot(ls="-")

# %%
plt.figure(figsize=(15,10))
f.close.plot(ls="-")
seven.plot(ls="--")
ten.plot(ls="-.")
twenty.plot(ls=":")
thirty.plot()
plt.legend(["close", "seven",'ten',"twenty", "thirty"])

# %%
plt.figure(figsize=(15,10))
f.close.plot(ls="-")
seven.plot(ls="--")
ten.plot(ls="-.")
twenty.plot(ls=":")
thirty.plot()
plt.legend(["close", "seven", "ten", "twenty", "thirty"])

# %%
# scatter Plots

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.plot.scatter("mpg", "weight")

# %%
mpg.plot.scatter(x="mpg", y="weight", c= "horsepower", cmap="coolwarm")

# %% [markdown]
# ## Hexagonal Bin Plot
#
# Useful for Bivariate Data, alternative to scatterplot:

# %%
#df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
#df.plot.hexbin(x='a',y='b',gridsize=25,cmap='Oranges')

# %%
mpg.plot.hexbin(x="mpg", y="weight", gridsize=25)

# %% [markdown]
# ## BoxPlots

# %%
mpg.weight.plot.box()

# %%
mpg.horsepower.plot.box()

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.boxplot(x="origin", y="mpg", data=mpg)

# %%
mpg.plot.box("origin", "mpg" )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-0c2fc5d6ce56> in <module>
# ----> 1 mpg.plot.box("origin", "mpg" )
#
# TypeError: box() takes from 1 to 2 positional arguments but 3 were given

# %%
mpg.plot.box()

# %%
mpg.boxplot(column='horsepower', by="origin")

# %%
mpg.boxplot(column="horsepower", by="origin");

# %%
mpg.horsepower.plot.kde()

# %%
mpg.horsepower.plot.density()

# %%
df = pd.read_csv("cleaned_autos.csv")

# %%
df
# Out:
#                 dateCrawled                                   name  seller  \
# 0       2016-03-24 11:52:17                             Golf_3_1.6  privat
# 1       2016-03-24 10:58:45                   A5_Sportback_2.7_Tdi  privat
# 2       2016-03-14 12:52:21         Jeep_Grand_Cherokee_"Overland"  privat
# 3       2016-03-17 16:54:04                     GOLF_4_1_4__3TÜRER  privat
# 4       2016-03-31 17:25:20         Skoda_Fabia_1.4_TDI_PD_Classic  privat
# ...                     ...                                    ...     ...
# 313682  2016-03-21 09:50:58                        Mitsubishi_Cold  privat
# 313683  2016-03-14 17:48:27             Suche_t4___vito_ab_6_sitze  privat
# 313684  2016-03-05 19:56:21  Smart_smart_leistungssteigerung_100ps  privat
# 313685  2016-03-19 18:57:12     Volkswagen_Multivan_T4_TDI_7DC_UY2  privat
# 313686  2016-03-20 19:41:08                 VW_Golf_Kombi_1_9l_TDI  privat
#
# ...

# %%
df.shape
# Out:
# (313687, 27)
