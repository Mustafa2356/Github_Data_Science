# %%
import matplotlib.pyplot as plt

# %%
# Functional method

# %%
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]
salary = [38496, 42000, 46752, 49320, 53200,
         56000, 62316, 64928, 67317, 68748, 73752]

# %%
plt.plot(age,salary)

# %%
plt.plot(age,salary)
plt.xlabel("age")
plt.ylabel("salary")
plt.title("salary by age")
# Out:
# Text(0.5, 1.0, 'salary by age')

# %%
salary_2 = [45372, 48876, 53850, 57287, 63016,
            65998, 70003, 70000, 71496, 75370, 83640]

# %%
plt.plot(age,salary)
plt.plot(age,salary_2)
plt.xlabel("age")
plt.ylabel("salary")
plt.title("salary by age")
# Out:
# Text(0.5, 1.0, 'salary by age')

# %%
plt.plot(age,salary, label='salary')    # tek axes de iki label
plt.plot(age,salary_2, label='salary_2')
plt.xlabel("age")
plt.ylabel("salary")
plt.title("salary by age")
plt.legend();

# %%
plt.subplot(2,1,1) # iki ayri axeste iki lable
plt.plot(age,salary, "r")
plt.subplot(2,1,2)
plt.plot(age,salary_2, "b")
plt.tight_layout();

# %%
plt.subplot(2,2,1) # iki ayri axeste iki lable
plt.plot(age,salary, "r")
plt.subplot(2,2,2)
plt.plot(age,salary_2, "b")
plt.tight_layout();

# %%
plt.subplot(2,2,1) 
plt.plot(age,salary, "r")

plt.subplot(2,2,3) 
plt.plot(age,salary, "r")

plt.subplot(2,2,2)
plt.plot(age,salary_2, "b")

plt.subplot(2,2,4)
plt.plot(age,salary_2, "b")



plt.tight_layout();

# %%
plt.subplot(2,3,1) 
plt.plot(age,salary, "r")

plt.subplot(2,3,3) 
plt.plot(age,salary, "r")

plt.subplot(2,3,2)
plt.plot(age,salary_2, "b")

plt.subplot(2,3,4)
plt.plot(age,salary_2, "b")

plt.subplot(2,3,5) 
plt.plot(age,salary, "r")

plt.subplot(2,3,6) 
plt.plot(age,salary, "r")

plt.tight_layout();

# %%
plt.subplot(3,2,1) 
plt.plot(age,salary, "r")

plt.subplot(3,2,2) 
plt.plot(age,salary, "r")

plt.subplot(3,2,3)
plt.plot(age,salary_2, "b")

plt.subplot(3,2,4)
plt.plot(age,salary_2, "b")

plt.subplot(3,2,5) 
plt.plot(age,salary, "r")

plt.subplot(3,2,6) 
plt.plot(age,salary, "r")

plt.tight_layout();

# %%
plt.plot(salary)

# %%
import pandas as pd
df = pd.DataFrame(list(zip(age, salary, salary_2)), columns =['age', 'salary', 'salary_2'])
df.head()
# Out:
#    age  salary  salary_2
# 0   25   38496     45372
# 1   27   42000     48876
# 2   29   46752     53850
# 3   31   49320     57287
# 4   33   53200     63016

# %%
df.salary
# Out:
# 0     38496
# 1     42000
# 2     46752
# 3     49320
# 4     53200
# 5     56000
# 6     62316
# 7     64928
# 8     67317
# 9     68748
# 10    73752
# Name: salary, dtype: int64

# %%
plt.plot(df.salary)

# %%
plt.plot(df["age"], df["salary"]); # plt.plot(age,salary) important

# %% [markdown]
# ## OOP_

# %%
## 1oop Manuel-

# %%
fig = plt.figure()

# %%
ax1 = fig.add_axes([0.0, 0.0, 0.8, 0.8])
# Out:
# <ipython-input-42-c595b2a18b31>:1: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax1 = fig.add_axes([0.0, 0.0, 0.8, 0.8])

# %%
ax1

# %%
fig = plt.figure()
ax = fig.add_axes([0.0, 0.0, 0.8, 0.8])
